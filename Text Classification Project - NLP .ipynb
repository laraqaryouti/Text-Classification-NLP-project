# %% [markdown]
# ## Text Classification Project
#
# The purpose of this project is to correctly assign news articles the correct category (sports, political, and historical)
# using a dataset of 12 english files and 12 arabic files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import ISRIStemmer
import os
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\laraq\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\laraq\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\laraq\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# ### 1. Annotating the articles with the correct labels

# %%
labeled_dataset = pd.read_csv('labeled_dataset.csv')
labeled_dataset
# Out:
#               Article        Class
# 0    English Article 1      Sports
# 1    English Article 2      Sports
# 2    English Article 3      Sports
# 3    English Article 4      Sports
# 4    English Article 5  Historical
# 5    English Article 6  Historical
# 6    English Article 7  Historical
# 7    English Article 8  Historical
# 8    English Article 9   Political
# 9   English Article 10   Political
# 10  English Article 11   Political
# 11  English Article 12   Political
# 12  English Article 13   Political
# 13  English Article 14  Historical
# 14  English Article 15  Historical
# 15  English Article 16      Sports
# 16  English Article 17  Historical
# 17  English Article 18   Political
# 18  English Article 19   Political
# 19  English Article 20      Sports
# 20  English Article 21  Historical
# 21  English Article 22   Political
# 22  English Article 23      Sports
# 23  English Article 24      Sports
# 24    Arabic Article 1      Sports
# 25    Arabic Article 2      Sports
# 26    Arabic Article 3      Sports
# 27    Arabic Article 4      Sports
# 28    Arabic Article 5  Historical
# 29    Arabic Article 6  Historical
# 30    Arabic Article 7  Historical
# 31    Arabic Article 8  Historical
# 32    Arabic Article 9   Political
# 33   Arabic Article 10   Political
# 34   Arabic Article 11   Political
# 35   Arabic Article 12   Political
# 36   Arabic Article 13      Sports
# 37   Arabic Article 14      Sports
# 38   Arabic Article 15      Sports
# 39   Arabic Article 16   Political
# 40   Arabic Article 17  Historical
# 41   Arabic Article 18      Sports
# 42   Arabic Article 19   Political
# 43   Arabic Article 20  Historical
# 44   Arabic Article 21   Political
# 45   Arabic Article 22   Political
# 46   Arabic Article 23  Historical
# 47   Arabic Article 24  Historical

# %% [markdown]
# ### 2. Data Preprocessing
# this step includes tokenization, stopwords removal, converting to lower-case letters, and stemming

# %%
def data_preprocessing_english(text):
    words = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_words = []
    for word in words:
        if word.isalnum() and word.lower() not in stop_words:
            filtered_words.append(word.lower())
    lowercased_filtered_words = []
    for word in filtered_words:
        lowercased_filtered_words.append(word.lower())
    ps = PorterStemmer()
    stemmed_words = []
    for word in filtered_words:
        stemmed_words.append(ps.stem(word))
    return stemmed_words

# %%
def data_preprocessing_arabic(text):
    words = word_tokenize(text)
    stop_words = set(stopwords.words('arabic'))
    filtered_words = [word for word in words if word.isalnum() and word.lower() not in stop_words]
    stemmer = ISRIStemmer()
    stemmed_words = [stemmer.stem(word) for word in filtered_words]
    return stemmed_words

# %%
directory = "data/"
english_results = {}
arabic_results = {}
english_file_names = [f'20200455_{i:02d}_E.txt' for i in range(1, 25)]
for file_name in english_file_names:
    file_path = os.path.join(directory, file_name)

    with open(file_path, 'rb') as file:
        data = file.read()
        data_decoded = data.decode()
        preprocessed_text = data_preprocessing_english(data_decoded)
        english_results[file_name] = preprocessed_text

# %%
arabic_file_names = [f'20200455_{i:02d}_A.txt' for i in range(1, 25)]
for file_name in arabic_file_names:
    file_path = os.path.join(directory, file_name)
    with open(file_path, 'rb') as file:
        data = file.read()
        data_decoded = data.decode()
        preprocessed_text = data_preprocessing_arabic(data_decoded)
        arabic_results[file_name] = preprocessed_text

# %%
english_results
# Out:
# {'20200455_01_E.txt': ['us',
#   'open',
#   'women',
#   'semifin',
#   'coco',
#   'gauff',
#   'madison',
#   'key',
#   'lead',
#   'american',
#   'quest',
#   'home',
#   'glori',
#   'fan',
#   'might',
#   'rememb',
#   'specif',
#   'take',
#   'place',
#   'recent',
#   'two',
#   'took',
#   'court',
#   'three',
#   'week',
#   'ago',
#   'final',
#   'western',
#   'southern',
#   'open',
#   'cincinnati',
#   'gauff',
#   'win',
#   'straight',
#   'set',
#   'claim',
#   'biggest',
#   'titl',
#   'career',
#   'victori',
#   'ohio',
#   'came',
#   'midst',
#   'gauff',
#   'best',
#   'period',
#   'form',
#   'blossom',
#   'tenni',
#   'career',
#   'momentum',
#   'continu',
#   'us',
#   'open',
#   'american',
#   'recent',
#   'outing',
#   'flush',
#   'meadow',
#   'anoth',
#   'impress',
#   'perform',
#   'beat',
#   'jelena',
#   'ostapenko',
#   'eas',
#   '10th',
#   'victori',
#   'row',
#   'somewhat',
#   'tournament',
#   'gauff',
#   'look',
#   'like',
#   'seriou',
#   'contend',
#   'win',
#   'maiden',
#   'grand',
#   'slam',
#   'titl',
#   'insist',
#   'get',
#   'ahead',
#   'still',
#   'lot',
#   'tenni',
#   'left',
#   'play',
#   'gauff',
#   'said',
#   'still',
#   'mindset',
#   'begin',
#   'tournament',
#   'would',
#   'think',
#   'close',
#   'end',
#   'right',
#   'mental',
#   'told',
#   'still',
#   'anoth',
#   'two',
#   'week',
#   'play',
#   'right',
#   'feel',
#   'emot',
#   'fresh',
#   'think',
#   'problem',
#   'past',
#   'grand',
#   'slam',
#   'would',
#   'emot',
#   'muchová',
#   'much',
#   'seen',
#   'underdog',
#   'gauff',
#   'despit',
#   'also',
#   'show',
#   'excel',
#   'form',
#   'recent',
#   'rise',
#   'rank',
#   '10',
#   'world',
#   'czech',
#   'lost',
#   'final',
#   'french',
#   'open',
#   'earlier',
#   'year',
#   'drop',
#   'one',
#   'set',
#   'en',
#   'rout',
#   'semifin',
#   'continu',
#   'extraordinari',
#   'comeback',
#   'season',
#   'suffer',
#   'seri',
#   'injuri',
#   'last',
#   'year',
#   'threaten',
#   'career'],
#  '20200455_02_E.txt': ['olymp',
#   'swim',
#   'test',
#   'event',
#   'sein',
#   'cancel',
#   'due',
#   'poor',
#   'water',
#   'qualiti',
#   'swim',
#   'competit',
#   'suppos',
#   'serv',
#   'test',
#   'event',
#   'ahead',
#   '2024',
#   'pari',
#   'olymp',
#   'cancel',
#   'due',
#   'poor',
#   'water',
#   'qualiti',
#   'sein',
#   'cast',
#   'doubt',
#   'french',
#   'govern',
#   'audaci',
#   'plan',
#   'clean',
#   'famou',
#   'river',
#   'next',
#   'summer',
#   'world',
#   'aquat',
#   'intern',
#   'govern',
#   'bodi',
#   'swim',
#   'water',
#   'sport',
#   'pari',
#   '2024',
#   'organ',
#   'committe',
#   'said',
#   'rainfal',
#   'juli',
#   'left',
#   'sein',
#   'pollut',
#   'swim',
#   'decis',
#   'cancel',
#   'event',
#   'open',
#   'water',
#   'swim',
#   'world',
#   'cup',
#   'made',
#   'world',
#   'aquat',
#   'consult',
#   'french',
#   'swim',
#   'feder',
#   'ffn',
#   'public',
#   'health',
#   'author',
#   'world',
#   'aquat',
#   'disappoint',
#   'water',
#   'qualiti',
#   'sein',
#   'result',
#   'cancel',
#   'world',
#   'aquat',
#   'open',
#   'water',
#   'swim',
#   'world',
#   'cup',
#   'health',
#   'athlet',
#   'must',
#   'alway',
#   'top',
#   'prioriti',
#   'said',
#   'world',
#   'aquat',
#   'presid',
#   'husain',
#   'olymp',
#   'organ',
#   'express',
#   'confid',
#   'sein',
#   'would',
#   'better',
#   'prepar',
#   'swimmer',
#   'game',
#   'open',
#   'next',
#   'year',
#   'pari',
#   '2024',
#   'organ',
#   'committe',
#   'statement',
#   'new',
#   'infrastructur',
#   'put',
#   'place',
#   'improv',
#   'water',
#   'treatment',
#   'raini',
#   'weather',
#   'start',
#   'pari',
#   'olymp',
#   'conting',
#   'measur',
#   'postpon',
#   'competit',
#   'due',
#   'water',
#   'qualiti',
#   'also',
#   'plan',
#   'pari',
#   'plan',
#   'make',
#   'river',
#   'sein',
#   'centerpiec',
#   'olymp',
#   'featur',
#   'promin',
#   'open',
#   'ceremoni',
#   'sever',
#   'swim',
#   'event',
#   'paratriathlon',
#   'triathlon',
#   'event',
#   'set',
#   'take',
#   'place',
#   'water',
#   'clean',
#   'effort',
#   'underway',
#   'sinc',
#   '2018',
#   'two',
#   'disinfect',
#   'unit',
#   'wastewat',
#   'treatment',
#   'plant',
#   'run',
#   'pari',
#   'region',
#   'public',
#   'sanit',
#   'servic',
#   'oper',
#   'summer',
#   'structur',
#   'help',
#   'improv',
#   'water',
#   'qualiti',
#   'rainwat',
#   'storag',
#   'basin',
#   'construct'],
#  '20200455_03_E.txt': ['india',
#   'beat',
#   'pakistan',
#   'cricket',
#   'world',
#   'cup',
#   'sport',
#   'rivalri',
#   'like',
#   'fan',
#   'pack',
#   'insid',
#   'enorm',
#   'narendra',
#   'modi',
#   'stadium',
#   'ahmedabad',
#   'india',
#   'watch',
#   'india',
#   'take',
#   'pakistan',
#   'icc',
#   'men',
#   'cricket',
#   'world',
#   'cup',
#   'saturday',
#   'front',
#   'sea',
#   'blue',
#   'india',
#   'shirt',
#   'punctuat',
#   'flash',
#   'green',
#   'orang',
#   'white',
#   'peopl',
#   'wave',
#   'india',
#   'flag',
#   'home',
#   'team',
#   'secur',
#   'thump',
#   'victori',
#   'pakistan',
#   'often',
#   'describ',
#   'one',
#   'greatest',
#   'sport',
#   'grudg',
#   'match',
#   'world',
#   'cricket',
#   'match',
#   'alway',
#   'bound',
#   'geopolit',
#   'faultlin',
#   'separ',
#   'two',
#   'nation',
#   'small',
#   'pocket',
#   'pakistan',
#   'fan',
#   'incred',
#   'difficult',
#   'travel',
#   'india',
#   'due',
#   'red',
#   'tape',
#   'histor',
#   'mistrust',
#   'restrict',
#   'movement',
#   'citizen',
#   'countri',
#   'larg',
#   'absent',
#   'crowd',
#   'pakistan',
#   'head',
#   'coach',
#   'mickey',
#   'arthur',
#   'said',
#   'afterward',
#   'per',
#   'reuter',
#   'event',
#   'seem',
#   'like',
#   'bilater',
#   'seri',
#   'rather',
#   'world',
#   'cup',
#   'hear',
#   'dil',
#   'dil',
#   'pakistan',
#   'countri',
#   'unoffici',
#   'anthem',
#   'come',
#   'microphon',
#   'ye',
#   'play',
#   'role',
#   'go',
#   'use',
#   'excus',
#   'us',
#   'live',
#   'moment',
#   'next',
#   'ball',
#   'go',
#   'combat',
#   'indian',
#   'player',
#   'tonight',
#   'ad',
#   'two',
#   'team',
#   'play',
#   'seven',
#   'year',
#   'indian',
#   'soil',
#   'pakistan',
#   'never',
#   'defeat',
#   'india',
#   'men',
#   'world',
#   'cup',
#   'initi',
#   'seem',
#   'record',
#   'might',
#   'threat',
#   'pakistan',
#   'began',
#   'strongli',
#   'en',
#   'rout',
#   'set',
#   'competit',
#   'total',
#   'captain',
#   'babar',
#   'azam',
#   'mohammad',
#   'rizwan',
#   'put',
#   '82',
#   'run',
#   'third',
#   'wicket',
#   'babar',
#   'score',
#   'first',
#   'time',
#   'odi',
#   'match',
#   'india'],
#  '20200455_04_E.txt': ['europ',
#   'hold',
#   'late',
#   'usa',
#   'comeback',
#   'regain',
#   'ryder',
#   'cup',
#   'europ',
#   'surviv',
#   'sunday',
#   'scare',
#   'regain',
#   'ryder',
#   'cup',
#   'hold',
#   'late',
#   'us',
#   'fightback',
#   'win',
#   'rome',
#   'suffer',
#   'record',
#   'defeat',
#   'whistl',
#   'strait',
#   '2021',
#   'host',
#   'made',
#   'feroci',
#   'start',
#   'marco',
#   'simon',
#   'golf',
#   'club',
#   'maintain',
#   'pace',
#   'take',
#   'command',
#   'point',
#   'lead',
#   'final',
#   'day',
#   'singl',
#   'match',
#   'yet',
#   'move',
#   'within',
#   'half',
#   'point',
#   'win',
#   'threshold',
#   'insid',
#   'open',
#   'six',
#   'game',
#   'wait',
#   'ensu',
#   'visitor',
#   'accumul',
#   'flurri',
#   'win',
#   'keep',
#   'dream',
#   'first',
#   'away',
#   'triumph',
#   '30',
#   'year',
#   'aliv',
#   'europ',
#   'rise',
#   'anxieti',
#   'final',
#   'quell',
#   'england',
#   'tommi',
#   'fleetwood',
#   'face',
#   'ricki',
#   'fowler',
#   'penultim',
#   'match',
#   'struck',
#   'sensat',
#   'tee',
#   'shot',
#   'help',
#   'take',
#   '16th',
#   'hole',
#   'guarante',
#   'least',
#   'tie',
#   'singl',
#   'match',
#   'consequ',
#   'ryder',
#   'cup',
#   'confirm',
#   'spark',
#   'euphor',
#   'scene',
#   'among',
#   'team',
#   'europ',
#   'tear',
#   'captain',
#   'luke',
#   'donald',
#   'long',
#   'process',
#   'amaz',
#   'journey',
#   'emot',
#   'donald',
#   'said',
#   'tv',
#   'interview',
#   'stress',
#   'usa',
#   'put',
#   'fight',
#   'today',
#   'realli',
#   'hat',
#   'proud',
#   '12',
#   'guy',
#   'form',
#   'bond',
#   'day',
#   'one',
#   'gave',
#   'everyth',
#   'ryder',
#   'cup',
#   'special',
#   'guy',
#   'play',
#   'share',
#   'memori',
#   'brief',
#   'interlud',
#   'close',
#   'match',
#   'finish',
#   'crowd',
#   'flood',
#   'onto',
#   'cours',
#   'surround',
#   '18th',
#   'green',
#   'republ',
#   'ireland',
#   'shane',
#   'lowri',
#   'play',
#   'undoubtedli',
#   'enjoy',
#   'lost',
#   'hole',
#   'career',
#   'tie',
#   'jordan',
#   'spieth'],
#  '20200455_05_E.txt': ['ancient',
#   'greek',
#   'built',
#   'road',
#   'primit',
#   'railway',
#   'haul',
#   'cargo',
#   'overland',
#   'locat',
#   'isthmu',
#   'west',
#   'athen',
#   'ancient',
#   'corinth',
#   'power',
#   'wealthi',
#   'citi',
#   'control',
#   'commerc',
#   'land',
#   'sea',
#   'region',
#   'home',
#   'isthmian',
#   'game',
#   'held',
#   'honor',
#   'sea',
#   'god',
#   'poseidon',
#   'oliv',
#   'oil',
#   'wine',
#   'textil',
#   'potteri',
#   'form',
#   'exot',
#   'trade',
#   'flow',
#   'throughout',
#   'region',
#   'south',
#   'corinth',
#   'isthmu',
#   'cape',
#   'malea',
#   'tore',
#   'vessel',
#   'piec',
#   'plung',
#   'sailor',
#   'death',
#   'homer',
#   'greek',
#   'epic',
#   'odyssey',
#   'heroic',
#   'odysseu',
#   'tri',
#   'sail',
#   'danger',
#   'water',
#   'blown',
#   'path',
#   'end',
#   'land',
#   'rather',
#   'brave',
#   'treacher',
#   'southern',
#   'rout',
#   'ancient',
#   'travel',
#   'use',
#   'diolko',
#   'bridg',
#   'distanc',
#   'corinth',
#   'primari',
#   'western',
#   'eastern',
#   'port',
#   'centuri',
#   'later',
#   '67',
#   'roman',
#   'emperor',
#   'nero',
#   'attempt',
#   'build',
#   'canal',
#   'corinth',
#   'port',
#   'use',
#   'thousand',
#   'slave',
#   'project',
#   'soon',
#   'abandon',
#   'construct',
#   'modern',
#   'narrow',
#   'corinth',
#   'canal',
#   'start',
#   '1882',
#   'complet',
#   '1893',
#   'start',
#   'late',
#   '1950',
#   'archaeologist',
#   'nikolao',
#   'verd',
#   'excav',
#   'part',
#   'diolko',
#   'date',
#   'around',
#   '600',
#   'reign',
#   'periand',
#   'second',
#   'tyrant',
#   'cypselid',
#   'dynasti',
#   'rule',
#   'ancient',
#   'corinth',
#   'one',
#   'legend',
#   'say',
#   'periand',
#   'built',
#   'road',
#   'instead',
#   'canal',
#   'priest',
#   'warn',
#   'anger',
#   'two',
#   'ocean',
#   'mingl',
#   'would',
#   'result',
#   'downfal',
#   'corinth',
#   'ship',
#   'approach',
#   'coast',
#   'via',
#   'gulf',
#   'corinth',
#   'haul',
#   'slope',
#   'jetti',
#   'west',
#   'end',
#   'probabl',
#   'underwat',
#   'upon',
#   'wooden',
#   'roller',
#   'hoist',
#   'onto',
#   'wheel',
#   'vehicl',
#   'say',
#   'spyropoulo',
#   'mani',
#   'wagon',
#   'laden',
#   'heavi',
#   'cargo',
#   'like',
#   'timber',
#   'marbl',
#   'pull',
#   'anim'],
#  '20200455_06_E.txt': ['alexand',
#   'grew',
#   'ancient',
#   'greek',
#   'kingdom',
#   'macedonia',
#   'conquer',
#   'persian',
#   'empir',
#   'alexand',
#   'great',
#   'stand',
#   'one',
#   'icon',
#   'militari',
#   'leader',
#   'histori',
#   '336',
#   'bce',
#   'age',
#   '20',
#   'succeed',
#   'father',
#   'philip',
#   'ii',
#   'king',
#   'greek',
#   'kingdom',
#   'macedonia',
#   'began',
#   'seri',
#   'aggress',
#   'militari',
#   'campaign',
#   'secur',
#   'territori',
#   'alreadi',
#   'expand',
#   'rule',
#   'eastward',
#   'king',
#   'alexand',
#   'success',
#   'conquer',
#   'first',
#   'persian',
#   'empir',
#   'extend',
#   'macedonia',
#   'territori',
#   'far',
#   'pakistan',
#   'india',
#   'campaign',
#   'spread',
#   'greek',
#   'cultur',
#   'across',
#   'middl',
#   'east',
#   'boost',
#   'develop',
#   'hellenist',
#   'cultur',
#   'death',
#   '323',
#   'bce',
#   'alexand',
#   'militari',
#   'career',
#   'stand',
#   'mani',
#   'victori',
#   'even',
#   'forc',
#   'sever',
#   'outnumb',
#   'historian',
#   'also',
#   'note',
#   'reportedli',
#   'alway',
#   'insist',
#   'lead',
#   'troop',
#   'front',
#   'line',
#   'battl',
#   'result',
#   'sustain',
#   'numer',
#   'seriou',
#   'cleaver',
#   'slash',
#   'head',
#   'sword',
#   'gash',
#   'thigh',
#   'catapult',
#   'missil',
#   'lodg',
#   'shoulder',
#   'arrow',
#   'pierc',
#   'lung',
#   'allegedli',
#   'almost',
#   'kill',
#   'alexand',
#   'signific',
#   'battl',
#   'plu',
#   'one',
#   'sieg',
#   'last',
#   'effect',
#   'environ',
#   'still',
#   'observ',
#   'today',
#   'greek',
#   'thebe',
#   'confus',
#   'egyptian',
#   'citi',
#   'thebe',
#   'revolt',
#   'macedonian',
#   'rule',
#   'alexand',
#   'march',
#   'troop',
#   'put',
#   'revolut',
#   'win',
#   'alexand',
#   'first',
#   'major',
#   'macedonian',
#   'conqueror',
#   'proceed',
#   'torch',
#   'citi',
#   'paul',
#   'cartledg',
#   'professor',
#   'emeritu',
#   'greek',
#   'cultur',
#   'univers',
#   'cambridg',
#   'say',
#   'one',
#   'reason',
#   'alexand',
#   'burn',
#   'thebe',
#   'warn',
#   'greek',
#   'rebel',
#   'macedonian',
#   'rule',
#   'strategi',
#   'quit',
#   'work',
#   'sparta',
#   'revolt',
#   'albeit',
#   'unsuccess',
#   '331',
#   'bce',
#   'time',
#   'alexand',
#   'asia',
#   'take',
#   'persian',
#   'empir'],
#  '20200455_07_E.txt': ['histor',
#   'theater',
#   'england',
#   'claim',
#   'found',
#   'bard',
#   'surviv',
#   'stage',
#   'william',
#   'shakespear',
#   'famous',
#   'wrote',
#   'world',
#   'stage',
#   'offici',
#   'theater',
#   'norfolk',
#   'england',
#   'claim',
#   'found',
#   'surviv',
#   'stage',
#   'bard',
#   'perform',
#   'recent',
#   'restor',
#   'board',
#   'discov',
#   'layer',
#   'floor',
#   'georg',
#   'guildhal',
#   'king',
#   'lynn',
#   'unit',
#   'kingdom',
#   'oldest',
#   'work',
#   'theater',
#   'larg',
#   'oak',
#   'board',
#   'almost',
#   '30',
#   'centimet',
#   '12',
#   'inch',
#   'wide',
#   '15',
#   'centimet',
#   '6',
#   'inch',
#   'thick',
#   'held',
#   'togeth',
#   'wooden',
#   'peg',
#   'instead',
#   'nail',
#   'tim',
#   'fitzhigham',
#   'guildhal',
#   'creativ',
#   'director',
#   'tell',
#   'new',
#   'york',
#   'time',
#   'derrick',
#   'bryson',
#   'taylor',
#   'discoveri',
#   'realli',
#   'realli',
#   'excit',
#   'pretti',
#   'archaeologist',
#   'jonathan',
#   'clark',
#   'expert',
#   'mediev',
#   'build',
#   'lead',
#   'research',
#   'studi',
#   'wooden',
#   'board',
#   'two',
#   'month',
#   'tri',
#   'date',
#   'floor',
#   'examin',
#   'construct',
#   'method',
#   'use',
#   'build',
#   'well',
#   'growth',
#   'ring',
#   'seen',
#   'surviv',
#   'wood',
#   'base',
#   'detail',
#   'say',
#   'floorboard',
#   'date',
#   'earli',
#   '15th',
#   'centuri',
#   'like',
#   '1417',
#   '1430',
#   'fitzhigham',
#   'claim',
#   'shakespear',
#   'must',
#   'perform',
#   'document',
#   'show',
#   'bard',
#   'act',
#   'venu',
#   'late',
#   '16th',
#   'centuri',
#   'accord',
#   'bbc',
#   'news',
#   'colin',
#   'paterson',
#   'borough',
#   'account',
#   'book',
#   'record',
#   'borough',
#   'paid',
#   'shakespear',
#   'compani',
#   'come',
#   'play',
#   'venu',
#   'say',
#   'sinc',
#   'floorboard',
#   'instal',
#   'long',
#   '1590',
#   'like',
#   'surfac',
#   'shakespear',
#   'walk',
#   'clark',
#   'tell',
#   'bbc',
#   'news',
#   'end',
#   'hall',
#   'perform',
#   'took',
#   'place'],
#  '20200455_08_E.txt': ['untouch',
#   'ancient',
#   'tomb',
#   'belong',
#   'divin',
#   'inspector',
#   'uncov',
#   'egypt',
#   'known',
#   'wahty',
#   'serv',
#   'royal',
#   'priest',
#   'religi',
#   'figur',
#   'carri',
#   'titl',
#   'divin',
#   'must',
#   'someon',
#   'great',
#   'import',
#   'buri',
#   'southwest',
#   'outskirt',
#   'cairo',
#   'tomb',
#   'fill',
#   'colour',
#   'elabor',
#   'stone',
#   'carv',
#   'give',
#   'sens',
#   'ritual',
#   'life',
#   'death',
#   'ancient',
#   'egypt',
#   'year',
#   'ago',
#   'egyptian',
#   'antiqu',
#   'author',
#   'unveil',
#   'wahty',
#   'tomb',
#   'press',
#   'confer',
#   'saqqara',
#   'southwest',
#   'cairo',
#   'weekend',
#   'announc',
#   'plan',
#   'dig',
#   'deeper',
#   'complex',
#   'discov',
#   'excav',
#   'work',
#   'began',
#   'april',
#   'astonishingli',
#   'tomb',
#   'provid',
#   'insight',
#   'life',
#   '24th',
#   'centuri',
#   'bc',
#   'reign',
#   'fifth',
#   'dynasti',
#   'egyptian',
#   'king',
#   'neferirkar',
#   'kakair',
#   'time',
#   'rel',
#   'prosper',
#   'order',
#   'archaeologist',
#   'begin',
#   'inspect',
#   'five',
#   'shaft',
#   'led',
#   'tomb',
#   'believ',
#   'one',
#   'lead',
#   'wahty',
#   'sarcophagu',
#   'yet',
#   'discov',
#   'chamber',
#   'wall',
#   'includ',
#   'scene',
#   'show',
#   'wahty',
#   'wife',
#   'name',
#   'weret',
#   'ptah',
#   'mother',
#   'rel',
#   'well',
#   'depict',
#   'potteri',
#   'furnitur',
#   'wine',
#   'product',
#   'religi',
#   'ritual',
#   'music',
#   'perform',
#   'naval',
#   'vessel',
#   'men',
#   'hunt',
#   'anim',
#   'accord',
#   'egypt',
#   'ministri',
#   'antiqu',
#   'mostafa',
#   'waziri',
#   'egypt',
#   'suprem',
#   'council',
#   'antiqu',
#   'describ',
#   'discoveri',
#   'one',
#   'kind',
#   'recent',
#   'decad',
#   'colour',
#   'almost',
#   'intact',
#   'even',
#   'though',
#   'tomb',
#   'almost',
#   'year',
#   'old',
#   'reportedli',
#   'said',
#   'accord',
#   'reuter',
#   'nearli',
#   'two',
#   'dozen',
#   'foreign',
#   'diplomat',
#   'member',
#   'egypt',
#   'parliament',
#   'head',
#   'intern',
#   'archaeolog',
#   'mission',
#   'institut',
#   'attend',
#   'unveil',
#   'tomb',
#   'saturday',
#   'egyptian',
#   'author',
#   'tout',
#   'archaeolog',
#   'discoveri',
#   'effort',
#   'entic',
#   'tourist',
#   'back',
#   'countri',
#   'follow',
#   'year',
#   'turmoil',
#   'ignit',
#   'arab',
#   'spring',
#   'upris'],
#  '20200455_09_E.txt': ['presid',
#   'push',
#   'gun',
#   'safeti',
#   'hunter',
#   'biden',
#   'mount',
#   'second',
#   'amend',
#   'defens',
#   'hunter',
#   'biden',
#   'tuesday',
#   'plung',
#   'burgeon',
#   'second',
#   'amend',
#   'fight',
#   'whether',
#   'govern',
#   'disarm',
#   'peopl',
#   'use',
#   'illeg',
#   'drug',
#   'lawyer',
#   'presid',
#   'son',
#   'repeatedli',
#   'said',
#   'defend',
#   'three',
#   'feder',
#   'gun',
#   'charg',
#   'argu',
#   'main',
#   'feder',
#   'law',
#   'charg',
#   'unconstitut',
#   'light',
#   'recent',
#   'suprem',
#   'court',
#   'rule',
#   'argument',
#   'stand',
#   'stark',
#   'contrast',
#   'presid',
#   'joe',
#   'biden',
#   'advocaci',
#   'stricter',
#   'gun',
#   'law',
#   'hunter',
#   'biden',
#   'arraign',
#   'wilmington',
#   'tuesday',
#   'legal',
#   'team',
#   'formal',
#   'signal',
#   'intent',
#   'mount',
#   'constitut',
#   'challeng',
#   'charg',
#   'accus',
#   'biden',
#   'possess',
#   'gun',
#   'drug',
#   'user',
#   'lie',
#   'feder',
#   'form',
#   'bought',
#   'biden',
#   'plead',
#   'guilti',
#   'arraign',
#   'decad',
#   'feder',
#   'gun',
#   'control',
#   'act',
#   'ban',
#   'drug',
#   'user',
#   'possess',
#   'gun',
#   '2022',
#   'suprem',
#   'court',
#   'dramat',
#   'expand',
#   'second',
#   'amend',
#   'right',
#   'way',
#   'obfusc',
#   'rule',
#   'gun',
#   'restrict',
#   'valid',
#   'resembl',
#   'gun',
#   'law',
#   'exist',
#   'found',
#   'era',
#   'rule',
#   'new',
#   'york',
#   'state',
#   'rifl',
#   'pistol',
#   'associ',
#   'bruen',
#   'teed',
#   'host',
#   'conflict',
#   'rule',
#   'close',
#   'today',
#   'gun',
#   'law',
#   'must',
#   'hew',
#   'late',
#   '1700',
#   'prohibit',
#   'among',
#   'gun',
#   'restrict',
#   'face',
#   'new',
#   'challeng',
#   'bruen',
#   'defend',
#   'argu',
#   'law',
#   'bar',
#   'peopl',
#   'carri',
#   'firearm',
#   'intox',
#   'simpli',
#   'becom',
#   'intox',
#   'past',
#   'hunter',
#   'biden',
#   'head',
#   'trial',
#   'next',
#   'year',
#   'becom',
#   'famou',
#   'defend',
#   'far',
#   'lean',
#   'second',
#   'amend',
#   'even',
#   'father',
#   'expect',
#   'make',
#   'gun',
#   'safeti',
#   'focu',
#   'reelect',
#   'campaign',
#   'sinc',
#   'take',
#   'offic',
#   'presid',
#   'taken',
#   'slew',
#   'execut',
#   'action',
#   'work',
#   'bipartisan',
#   'coalit',
#   'congress',
#   'pass',
#   'first',
#   'gun',
#   'legisl',
#   'law',
#   'nearli',
#   'three',
#   'decad',
#   'toughen',
#   'background',
#   'check',
#   'young',
#   'gun',
#   'buyer',
#   'help',
#   'state',
#   'implement',
#   'red',
#   'flag',
#   'law',
#   'keep',
#   'firearm',
#   'domest',
#   'violenc',
#   'offend',
#   'presid',
#   'took',
#   'step',
#   'last',
#   'month',
#   'announc',
#   'feder',
#   'offic',
#   'gun',
#   'violenc',
#   'prevent'],
#  '20200455_10_E.txt': ['protest',
#   'new',
#   'york',
#   'call',
#   'new',
#   'york',
#   'cri',
#   'free',
#   'palestin',
#   'rang',
#   'new',
#   'york',
#   'friday',
#   'thousand',
#   'protest',
#   'took',
#   'street',
#   'denounc',
#   'isra',
#   'bomb',
#   'gaza',
#   'strip',
#   'call',
#   'end',
#   'isra',
#   'occup',
#   'liber',
#   'palestinian',
#   'territori',
#   'protest',
#   'took',
#   'multipl',
#   'block',
#   'citi',
#   'serv',
#   'crossroad',
#   'religion',
#   'nation',
#   'span',
#   'world',
#   'larg',
#   'youth',
#   'protest',
#   'drew',
#   'demonstr',
#   'origin',
#   'sport',
#   'palestinian',
#   'flag',
#   'keffiyeh',
#   'accus',
#   'israel',
#   'genocid',
#   'call',
#   'us',
#   'withdraw',
#   'support',
#   'middl',
#   'eastern',
#   'alli',
#   'thousand',
#   'attempt',
#   'flee',
#   'southern',
#   'gaza',
#   'israel',
#   'warn',
#   'evacu',
#   'expect',
#   'ground',
#   'offens',
#   'extrem',
#   'worri',
#   'stop',
#   'said',
#   'liz',
#   'zacharia',
#   'professor',
#   'attend',
#   'march',
#   'settler',
#   'coloni',
#   'project',
#   'israel',
#   'end',
#   'said',
#   'zacharia',
#   'whose',
#   'father',
#   'jerusalem',
#   'ad',
#   'feed',
#   'grow',
#   'cycl',
#   'violenc',
#   'oppress',
#   'palestinian',
#   'river',
#   'sea',
#   'palestin',
#   'free',
#   'protest',
#   'chant',
#   'multipl',
#   'protest',
#   'brooklyn',
#   'dozen',
#   'protest',
#   'arrest',
#   'friday',
#   'night',
#   'held',
#   'block',
#   'traffic',
#   'demonstr',
#   'front',
#   'home',
#   'senat',
#   'major',
#   'leader',
#   'chuck',
#   'schumer',
#   'democrat',
#   'plan',
#   'travel',
#   'congression',
#   'deleg',
#   'israel',
#   'call',
#   'organis',
#   'jewish',
#   'voic',
#   'peac',
#   'urg',
#   'elect',
#   'offici',
#   'stop',
#   'genocid',
#   'palestinian',
#   'gaza',
#   'protest',
#   'drew',
#   'mass',
#   'protest',
#   'front',
#   'strong',
#   'polic',
#   'presenc',
#   'arrest',
#   'includ',
#   'two',
#   'elect',
#   'offici',
#   'rabbi',
#   'descend',
#   'holocaust',
#   'survivor',
#   '200',
#   'demonstr',
#   'also',
#   'gather',
#   'southern',
#   'us',
#   'citi',
#   'miami',
#   'heavi',
#   'polic',
#   'presenc',
#   'guard',
#   'protest',
#   'made',
#   'sure',
#   'keep',
#   'distanc',
#   'dozen',
#   'demonstr',
#   'across',
#   'street',
#   'ana',
#   'amireh',
#   '51',
#   'businessman',
#   'son',
#   'palestinian',
#   'immigr',
#   'said',
#   'respond',
#   'kill',
#   'innoc',
#   'israel',
#   'anoth',
#   'genocid',
#   'gaza',
#   'strip',
#   'crimin',
#   'war',
#   'wrong'],
#  '20200455_11_E.txt': ['drug',
#   'war',
#   'spiral',
#   'ecuadoran',
#   'elect',
#   'new',
#   'presid',
#   'voter',
#   'ecuador',
#   'went',
#   'poll',
#   'sunday',
#   'choos',
#   'new',
#   'presid',
#   'midst',
#   'drug',
#   'war',
#   'rash',
#   'polit',
#   'assassin',
#   'cut',
#   'short',
#   'bid',
#   'popular',
#   'candid',
#   'finalist',
#   'runoff',
#   'elect',
#   'lawyer',
#   'luisa',
#   'gonzalez',
#   '45',
#   'banana',
#   'empir',
#   'heir',
#   'daniel',
#   'noboa',
#   '35',
#   'campaign',
#   'bulletproof',
#   'vest',
#   'climat',
#   'fear',
#   'grip',
#   'peac',
#   'south',
#   'american',
#   'countri',
#   'wore',
#   'vest',
#   'sunday',
#   'cast',
#   'ballot',
#   'protect',
#   'arm',
#   'bodyguard',
#   'vow',
#   'prioritis',
#   'deal',
#   'escal',
#   'violenc',
#   'long',
#   'line',
#   'form',
#   'outsid',
#   'vote',
#   'station',
#   'elect',
#   'unfold',
#   'amid',
#   'heavi',
#   'polic',
#   'presenc',
#   'although',
#   'immedi',
#   'report',
#   'violenc',
#   'critic',
#   'elect',
#   'freddi',
#   'escobar',
#   'popular',
#   'singer',
#   'told',
#   'afp',
#   'cite',
#   'crime',
#   'main',
#   'worri',
#   'vote',
#   'inde',
#   'main',
#   'concern',
#   'ecuadoran',
#   'accord',
#   'recent',
#   'poll',
#   'crime',
#   'violenc',
#   'countri',
#   'murder',
#   'rate',
#   'quadrupl',
#   'four',
#   'year',
#   '2022',
#   'polic',
#   'deploy',
#   'keep',
#   'vote',
#   'safe',
#   'first',
#   'preliminari',
#   'result',
#   'expect',
#   'earli',
#   'even',
#   'nation',
#   'elector',
#   'commiss',
#   'said',
#   'today',
#   'win',
#   'noboa',
#   'shout',
#   'pump',
#   'fist',
#   'air',
#   'vote',
#   'coastal',
#   'town',
#   'olon',
#   'live',
#   'gonzalez',
#   'predict',
#   'victori',
#   'cast',
#   'ballot',
#   'southwest',
#   'town',
#   'canuto',
#   'hunch',
#   'ecuador',
#   'win',
#   'word',
#   'citizen',
#   'revolut',
#   'said',
#   'refer',
#   'name',
#   'parti',
#   'drug',
#   'violenc',
#   'long',
#   'major',
#   'cocain',
#   'export',
#   'colombia',
#   'peru',
#   'ecuador',
#   'seen',
#   'violenc',
#   'explod',
#   'recent',
#   'year',
#   'enemi',
#   'gang',
#   'link',
#   'mexican',
#   'colombian',
#   'cartel',
#   'vie',
#   'control',
#   'fight',
#   'seen',
#   'least',
#   '460',
#   'inmat',
#   'massacr',
#   'prison',
#   'sinc',
#   'februari',
#   '2021',
#   'mani',
#   'behead',
#   'burn',
#   'aliv',
#   'mass',
#   'riot',
#   'bloodbath',
#   'spill',
#   'street',
#   'gang',
#   'dangl',
#   'headless',
#   'corps',
#   'citi',
#   'bridg',
#   'deton',
#   'car',
#   'bomb',
#   'outsid',
#   'polic',
#   'station',
#   'show',
#   'forc'],
#  '20200455_12_E.txt': ['jordan',
#   'field',
#   'hospit',
#   'gaza',
#   'await',
#   'vital',
#   'suppli',
#   'jordanian',
#   'field',
#   'hospit',
#   'gaza',
#   'despit',
#   'recent',
#   'inabl',
#   'provid',
#   'medic',
#   'servic',
#   'due',
#   'difficult',
#   'circumst',
#   'continu',
#   'oper',
#   'current',
#   'locat',
#   'strip',
#   'prime',
#   'minist',
#   'bisher',
#   'khasawneh',
#   'said',
#   'sunday',
#   'militari',
#   'field',
#   'hospit',
#   'maintain',
#   'presenc',
#   'gaza',
#   'approxim',
#   'two',
#   'decad',
#   'dedic',
#   'staff',
#   'prepar',
#   'resum',
#   'servic',
#   'soon',
#   'receiv',
#   'necessari',
#   'medic',
#   'suppli',
#   'current',
#   'inaccess',
#   'said',
#   'note',
#   'demonstr',
#   'jordan',
#   'commit',
#   'provid',
#   'assist',
#   'relief',
#   'peopl',
#   'gaza',
#   'express',
#   'kingdom',
#   'reject',
#   'forc',
#   'displac',
#   'prime',
#   'minist',
#   'emphasis',
#   'forc',
#   'displac',
#   'popul',
#   'clear',
#   'red',
#   'line',
#   'jordan',
#   'broader',
#   'arab',
#   'region',
#   'note',
#   'action',
#   'regard',
#   'war',
#   'crime',
#   'intern',
#   'law',
#   'primari',
#   'object',
#   'halt',
#   'ongo',
#   'aggress',
#   'militari',
#   'oper',
#   'enabl',
#   'establish',
#   'humanitarian',
#   'aid',
#   'corridor',
#   'reviv',
#   'polit',
#   'solut',
#   'said',
#   'sinc',
#   'begin',
#   'attack',
#   'civilian',
#   'gaza',
#   'majesti',
#   'king',
#   'abdullah',
#   'activ',
#   'work',
#   'coordin',
#   'intern',
#   'effort',
#   'aim',
#   'stop',
#   'escal',
#   'flagrant',
#   'aggress',
#   'civilian',
#   'gaza',
#   'ad',
#   'point',
#   'majesti',
#   'current',
#   'visit',
#   'four',
#   'european',
#   'capit',
#   'london',
#   'rome',
#   'berlin',
#   'pari',
#   'highlight',
#   'king',
#   'commun',
#   'world',
#   'leader',
#   'recent',
#   'day',
#   'aim',
#   'ensur',
#   'immedi',
#   'implement',
#   'intern',
#   'humanitarian',
#   'law',
#   'uphold',
#   'share',
#   'humanitarian',
#   'valu',
#   'safeguard',
#   'innoc',
#   'civilian',
#   'khasawneh',
#   'highlight',
#   'polit',
#   'solut',
#   'aim',
#   'end',
#   'conflict',
#   'within',
#   'framework',
#   'solut',
#   'lead',
#   'establish',
#   'independ',
#   'fulli',
#   'sovereign',
#   'palestinian',
#   'state',
#   'base',
#   'june',
#   '4',
#   '1967',
#   'line',
#   'east',
#   'jerusalem',
#   'capit',
#   'sole',
#   'solut',
#   'ensur',
#   'peac',
#   'region',
#   'stabil',
#   'highlight',
#   'jordan',
#   'effort',
#   'provid',
#   'humanitarian',
#   'assist',
#   'palestinian',
#   'gaza',
#   'strip',
#   'said',
#   'majesti',
#   'king',
#   'abdullah',
#   'issu',
#   'direct',
#   'dispatch',
#   'essenti',
#   'aid',
#   'note',
#   'immedi',
#   'respons',
#   'call',
#   'first',
#   'humanitarian',
#   'aid',
#   'plane',
#   'jordan',
#   'land',
#   'el',
#   'arish',
#   'airport',
#   'egypt',
#   'supervis',
#   'royal',
#   'jordanian',
#   'air',
#   'forc'],
#  '20200455_13_E.txt': ['unit',
#   'state',
#   'iran',
#   'engag',
#   'circular',
#   'address',
#   'reviv',
#   '2015',
#   'nuclear',
#   'deal',
#   'deal',
#   'design',
#   'limit',
#   'iran',
#   'nuclear',
#   'program',
#   'exchang',
#   'lift',
#   'profit',
#   'warrant',
#   'still',
#   'trump',
#   'administr',
#   'withdrew',
#   'deal',
#   '2018',
#   'iran',
#   'sinc',
#   'proceed',
#   'nuclear',
#   'condit',
#   'address',
#   'ongo',
#   'sever',
#   'month',
#   'littl',
#   'progress',
#   'unit',
#   'state',
#   'claim',
#   'iran',
#   'must',
#   'return',
#   'full',
#   'complianc',
#   'nuclear',
#   'deal',
#   'warrant',
#   'lift',
#   'iran',
#   'demand',
#   'unit',
#   'state',
#   'first',
#   'lift',
#   'warrant',
#   'return',
#   'complianc',
#   'outgrowth',
#   'address',
#   'uncertain',
#   'howev',
#   'could',
#   'lead',
#   'new',
#   'extrem',
#   'middl',
#   'east',
#   'address',
#   'fail'],
#  '20200455_14_E.txt': ['archaeologist',
#   'uncov',
#   'vast',
#   'ancient',
#   'megac',
#   'petén',
#   'jungl',
#   'guatemala',
#   'megac',
#   'believ',
#   'inhabit',
#   'maya',
#   'civil',
#   'estim',
#   'time',
#   'old',
#   'remain',
#   'megac',
#   'includ',
#   'conglomer',
#   'tabernacl',
#   'palac',
#   'discoveri',
#   'slip',
#   'new',
#   'light',
#   'maya',
#   'civil',
#   'impact',
#   'mesoamerica',
#   'megac',
#   'discov',
#   'use',
#   'fashion',
#   'call',
#   'lidar',
#   'use',
#   'spotlight',
#   'collud',
#   'face',
#   'earth',
#   'lidar',
#   'data',
#   'reveal',
#   'outlin',
#   'megac',
#   'hidden',
#   'thick',
#   'jungl',
#   'cover',
#   'archaeologist',
#   'sinc',
#   'begun',
#   'dig',
#   'point',
#   'uncov',
#   'number',
#   'vestig',
#   'includ',
#   'crockeri',
#   'obsidian',
#   'blade',
#   'wanton',
#   'jewelri',
#   'discoveri',
#   'ancient',
#   'megac',
#   'major',
#   'discoveri',
#   'archaeologist',
#   'largest',
#   'maya',
#   'megac',
#   'discov',
#   'guatemala',
#   'recent',
#   'decad',
#   'furnish',
#   'new',
#   'percept',
#   'maya',
#   'civil',
#   'archaeologist',
#   'believ',
#   'megac',
#   'formerli',
#   'major',
#   'center',
#   'power',
#   'commerc',
#   'hope',
#   'farther',
#   'excav',
#   'reveal',
#   'histori',
#   'cultur'],
#  '20200455_15_E.txt': ['scientist',
#   'discov',
#   'new',
#   'speci',
#   'mortal',
#   'ancestor',
#   'south',
#   'africa',
#   'speci',
#   'name',
#   'homo',
#   'naledi',
#   'believ',
#   'live',
#   'time',
#   'agon',
#   'discoveri',
#   'help',
#   'scientist',
#   'understand',
#   'elabor',
#   'mortal',
#   'rubric',
#   'remain',
#   'homo',
#   'naledi',
#   'set',
#   'deep',
#   'delv',
#   'system',
#   'cradl',
#   'humankind',
#   'unesco',
#   'world',
#   'heritag',
#   'site',
#   'locat',
#   'northwest',
#   'johannesburg',
#   'delv',
#   'system',
#   'known',
#   'rise',
#   'star',
#   'cave',
#   'one',
#   'richest',
#   'reactionari',
#   'spot',
#   'world',
#   'homo',
#   'naledi',
#   'fud',
#   'set',
#   'remot',
#   'chamber',
#   'rise',
#   'star',
#   'cave',
#   'known',
#   'dinaledi',
#   'chamber',
#   'chamber',
#   'delic',
#   'reach',
#   'believ',
#   'homo',
#   'naledi',
#   'individu',
#   'designedli',
#   'place',
#   'bodi',
#   'dead',
#   'chamber',
#   'homo',
#   'naledi',
#   'fud',
#   'major',
#   'discoveri',
#   'complet',
#   'hominin',
#   'fud',
#   'ever',
#   'set',
#   'africa',
#   'furnish',
#   'scientist',
#   'new',
#   'percept',
#   'elabor',
#   'mortal',
#   'rubric',
#   'fud',
#   'also',
#   'help',
#   'exfoli',
#   'light',
#   'relationship',
#   'homo',
#   'naledi',
#   'earli',
#   'mortal',
#   'speci',
#   'similar',
#   'homo',
#   'erectu',
#   'homo',
#   'neanderthalensi'],
#  '20200455_16_E.txt': ['esport',
#   'electron',
#   'sport',
#   'competit',
#   'videotap',
#   'game',
#   'play',
#   'profession',
#   'gamer',
#   'esport',
#   'come',
#   'major',
#   'onlook',
#   'sport',
#   'million',
#   'peopl',
#   'watch',
#   'event',
#   'event',
#   'onlin',
#   'esport',
#   'assidu',
#   'grow',
#   'fleetli',
#   'estim',
#   'worth',
#   'billion',
#   'bone',
#   'esport',
#   'particularli',
#   'popular',
#   'among',
#   'youth',
#   'peopl',
#   'seen',
#   'way',
#   'connect',
#   'musket',
#   'contend',
#   'other',
#   'around',
#   'world',
#   'rise',
#   'esport',
#   'reflect',
#   'chang',
#   'natur',
#   'entertain',
#   'esport',
#   'form',
#   'digit',
#   'entertain',
#   'consum',
#   'onlin',
#   'way'],
#  '20200455_17_E.txt': ['colosseum',
#   'ancient',
#   'theater',
#   'center',
#   'megac',
#   'rome',
#   'itali',
#   'erect',
#   'concret',
#   'graveston',
#   'largest',
#   'theater',
#   'ever',
#   'erect',
#   'consid',
#   'one',
#   'topmost',
#   'workshop',
#   'roman',
#   'armatur',
#   'engin',
#   'colosseum',
#   'ellipt',
#   'shape',
#   '188',
#   'measur',
#   'long',
#   '156',
#   'measur',
#   'wide',
#   'wall',
#   '57',
#   'measur',
#   'high',
#   'arena',
#   '86',
#   'measur',
#   'long',
#   '54',
#   'measur',
#   'wide',
#   'colosseum',
#   'could',
#   'hold',
#   'estim',
#   'observ',
#   'colosseum',
#   'use',
#   'confront',
#   'contest',
#   'beast',
#   'hunt',
#   'public',
#   'prosecut',
#   'also',
#   'use',
#   'religi',
#   'observ',
#   'carniv',
#   'colosseum',
#   'one',
#   'popular',
#   'sightseer',
#   'lodeston',
#   'rome',
#   'unesco',
#   'world',
#   'heritag',
#   'site',
#   'symbol',
#   'roman',
#   'empir',
#   'one',
#   'icon',
#   'mileston',
#   'world'],
#  '20200455_18_E.txt': ['unit',
#   'kingdom',
#   'face',
#   'polit',
#   'crisi',
#   'brexit',
#   'uk',
#   'vote',
#   'leav',
#   'european',
#   'union',
#   '2016',
#   'govern',
#   'unabl',
#   'agre',
#   'deal',
#   'eu',
#   'exit',
#   'led',
#   'great',
#   'deal',
#   'uncertainti',
#   'divis',
#   'uk',
#   'brexit',
#   'crisi',
#   'also',
#   'neg',
#   'impact',
#   'uk',
#   'economi',
#   'valu',
#   'pound',
#   'fallen',
#   'declin',
#   'invest',
#   'crisi',
#   'also',
#   'led',
#   'rise',
#   'hate',
#   'crime',
#   'xenophobia'],
#  '20200455_19_E.txt': ['european',
#   'union',
#   'face',
#   'major',
#   'energi',
#   'extrem',
#   'result',
#   'war',
#   'ukrain',
#   'eu',
#   'assess',
#   'warrant',
#   'russian',
#   'energi',
#   'export',
#   'russia',
#   'redress',
#   'cut',
#   'ga',
#   'inventori',
#   'europ',
#   'led',
#   'soar',
#   'energi',
#   'price',
#   'put',
#   'strain',
#   'busi',
#   'home',
#   'across',
#   'mainland',
#   'eu',
#   'scrabbl',
#   'find',
#   'indispens',
#   'sourc',
#   'energi',
#   'also',
#   'work',
#   'reduc',
#   'energi',
#   'consumpt',
#   'energi',
#   'extrem',
#   'major',
#   'challeng',
#   'eu',
#   'like',
#   'signific',
#   'impact',
#   'european',
#   'frugal',
#   'extrem',
#   'also',
#   'test',
#   'eu',
#   'concinn',
#   'member',
#   'countri',
#   'divid',
#   'respond'],
#  '20200455_20_E.txt': ['fifa',
#   'world',
#   'cup',
#   'popular',
#   'sport',
#   'event',
#   'world',
#   'held',
#   'everi',
#   'four',
#   'year',
#   'featur',
#   'top',
#   'nation',
#   'soccer',
#   'team',
#   'around',
#   'world',
#   'next',
#   'world',
#   'cup',
#   'held',
#   'qatar',
#   '2022',
#   'world',
#   'cup',
#   'major',
#   'event',
#   'countri',
#   'compet',
#   'also',
#   'major',
#   'event',
#   'busi',
#   'sponsor',
#   'tournament',
#   'fan',
#   'travel',
#   'watch',
#   'world',
#   'cup',
#   'truli',
#   'global',
#   'sport',
#   'event'],
#  '20200455_21_E.txt': ['experiment',
#   'set',
#   'substanti',
#   'earli',
#   'mortal',
#   'exert',
#   'north',
#   'america',
#   'knockout',
#   'thousand',
#   'time',
#   'age',
#   'preliminarili',
#   'allow',
#   'substanti',
#   'includ',
#   'graveston',
#   'tool',
#   'beast',
#   'bone',
#   'set',
#   'point',
#   'california',
#   'discoveri',
#   'suggest',
#   'human',
#   'may',
#   'arriv',
#   'north',
#   'america',
#   'much',
#   'earlier',
#   'preliminarili',
#   'believ',
#   'point',
#   'known',
#   'cerutti',
#   'mastodon',
#   'site',
#   'locat',
#   'near',
#   'citi',
#   'san',
#   'diego',
#   'experiment',
#   'set',
#   'number',
#   'graveston',
#   'tool',
#   'point',
#   'includ',
#   'scraper',
#   'copter',
#   'flake',
#   'also',
#   'set',
#   'bone',
#   'leviathan',
#   'larg',
#   'defunct',
#   'giant',
#   'leviathan',
#   'bone',
#   'date',
#   'time',
#   'old',
#   'much',
#   'age',
#   'former',
#   'substanti',
#   'mortal',
#   'exert',
#   'north',
#   'america',
#   'discoveri',
#   'cerutti',
#   'mastodon',
#   'site',
#   'major',
#   'advanc',
#   'studi',
#   'earli',
#   'mortal',
#   'migrat',
#   'suggest',
#   'human',
#   'may',
#   'arriv',
#   'north',
#   'america',
#   'much',
#   'earlier',
#   'preliminarili',
#   'allow',
#   'experiment',
#   'believ',
#   'point',
#   'may',
#   'butcher',
#   'point',
#   'human',
#   'kill',
#   'reus',
#   'leviathan',
#   'hope',
#   'farther',
#   'excav',
#   'reveal',
#   'earli',
#   'human',
#   'live',
#   'point'],
#  '20200455_22_E.txt': ['unit',
#   'state',
#   'china',
#   'engag',
#   'trade',
#   'war',
#   'signific',
#   'impact',
#   'countri',
#   'war',
#   'began',
#   '2018',
#   'trump',
#   'administr',
#   'assess',
#   'tariff',
#   'chines',
#   'good',
#   'china',
#   'redress',
#   'tariff',
#   'us',
#   'good',
#   'war',
#   'escal',
#   'sinc',
#   'also',
#   'unclear',
#   'end',
#   'trade',
#   'war',
#   'neg',
#   'impact',
#   'husbandri',
#   'countri',
#   'also',
#   'led',
#   'increas',
#   'pressur',
#   'two',
#   'countri',
#   'war',
#   'also',
#   'signific',
#   'impact',
#   'global',
#   'trade'],
#  '20200455_23_E.txt': ['women',
#   'sport',
#   'get',
#   'decreasingli',
#   'popular',
#   'around',
#   'world',
#   'recent',
#   'time',
#   'signific',
#   'increas',
#   'media',
#   'content',
#   'women',
#   'sport',
#   'girl',
#   'women',
#   'share',
#   'sport',
#   'lead',
#   'open',
#   'women',
#   'sport',
#   'world',
#   'athlet',
#   'trainer',
#   'director',
#   'broadcast',
#   'illustr',
#   'us',
#   'women',
#   'nation',
#   'soccer',
#   'team',
#   'one',
#   'popular',
#   'sport',
#   'brigad',
#   'unit',
#   'state',
#   'fifa',
#   'women',
#   'world',
#   'cup',
#   'one',
#   'watch',
#   'sport',
#   'event',
#   'world',
#   'rise',
#   'women',
#   'sport',
#   'posit',
#   'develop',
#   'gender',
#   'equival',
#   'furnish',
#   'girl',
#   'women',
#   'open',
#   'share',
#   'sport',
#   'achiev',
#   'full',
#   'eventu'],
#  '20200455_24_E.txt': ['nba',
#   'test',
#   'present',
#   'underway',
#   'golden',
#   'state',
#   'soldier',
#   'face',
#   'boston',
#   'celtic',
#   'soldier',
#   'defend',
#   'titlehold',
#   'seek',
#   'fourth',
#   'titl',
#   'eight',
#   'time',
#   'celtic',
#   'look',
#   'win',
#   'first',
#   'titl',
#   'sinc',
#   '2008',
#   'seri',
#   'verit',
#   'competit',
#   'platoon',
#   'win',
#   'two',
#   'game',
#   'soldier',
#   'led',
#   'stephen',
#   'curri',
#   'klay',
#   'thompson',
#   'draymond',
#   'green',
#   'celtic',
#   'led',
#   'jayson',
#   'tatum',
#   'jaylen',
#   'brown',
#   'marcu',
#   'smart',
#   'game',
#   '6',
#   'seri',
#   'play',
#   'decid',
#   'crown',
#   'seri',
#   'go',
#   'seventh',
#   'decid',
#   'game',
#   'celtic',
#   'win']}

# %%
arabic_results
# Out:
# {'20200455_01_A.txt': ['رسم',
#   'جزر',
#   'تضف',
#   'بري',
#   'نخب',
#   'لسط',
#   'كفل',
#   'مصاريف',
#   'خذت',
#   'جزر',
#   'عتق',
#   'ضاف',
#   'كفل',
#   'مصاريف',
#   'بري',
#   'قبل',
#   'نخب',
#   'كانت',
#   'ودة',
#   'اول',
#   '21',
#   'ضد',
#   'رال',
#   'تصف',
#   'زدج',
#   'ؤهل',
#   'لمونديال',
#   '2026',
#   'كأس',
#   'اسا',
#   'وفق',
#   'اعل',
#   'احد',
#   'تحد',
#   'جزر',
#   'لكر',
#   'قدم',
#   'وجء',
#   'قرر',
#   'لبي',
#   'طلب',
#   'قدم',
#   'رئس',
#   'تحد',
#   'لسط',
#   'لكر',
#   'قدم',
#   'جبريل',
#   'رجب',
#   'بهذا',
#   'خصص',
#   'سلط',
#   'جزر',
#   'وقل',
#   'تحد',
#   'جزر',
#   'عبة',
#   'بين',
#   'احد',
#   'نفذ',
#   'لتج',
#   'سلط',
#   'علا',
#   'بلد',
#   'بنء',
#   'طلب',
#   'رئس',
#   'تحد',
#   'لسط',
#   'لكر',
#   'سيد',
#   'جبريل',
#   'قرر',
#   'جزر',
#   'ضاف',
#   'بري',
#   'نخب',
#   'لسط',
#   'لكر',
#   'قدم',
#   'تصف',
#   'كأس',
#   'علم',
#   '2026',
#   'كأس',
#   'اسا',
#   'امم',
#   'كفل',
#   'بكل',
#   'كلف',
#   'تعلق',
#   'بهذ',
#   'حدث',
#   'ريض',
#   'تبع',
#   'يعل',
#   'رئس',
#   'تحد',
#   'جزر',
#   'لكر',
#   'قدم',
#   'سيد',
#   'ولد',
#   'بلد',
#   'تضف',
#   'برا',
#   'رسم',
#   'لسط',
#   'قرر',
#   'جرؤ',
#   'يوم',
#   '21',
#   'والتي',
#   'دخل',
#   'اطر',
#   'تصف',
#   'كأس',
#   'علم',
#   '2026',
#   'وقع',
#   'نخب',
#   'لسط',
#   'تصف',
#   'زدج',
#   'ؤهل',
#   'لمونديال',
#   'قرر',
#   'ولي',
#   'تحد',
#   'كسك',
#   'نهئ',
#   'كأس',
#   'اسا',
#   '2027',
#   'قرر',
#   'ضمن',
#   'جمع',
#   'اسع',
#   'تضم',
#   'رال',
#   'ولب',
#   'تأهل',
#   'دور',
#   'اول',
#   'مالديف',
#   'وبنغلادش',
#   'عدل',
#   'ذهب',
#   'ايب',
#   'ثلاثاء',
#   'يشر',
#   'نخب',
#   'لسط',
#   'نهي',
#   'كأس',
#   'اسا',
#   'قبل',
#   'قرر',
#   '12',
#   'و10',
#   '2024',
#   'لعب',
#   'ضمن',
#   'جمع',
#   'ثلث',
#   'جنب',
#   'اير',
#   'امر',
#   'هونغ',
#   'كونغ'],
#  '20200455_02_A.txt': ['أهل',
#   'ترك',
#   'إسب',
#   'وأسكتلندا',
#   'بطل',
#   'ورب',
#   '2024',
#   'أهل',
#   'ترك',
#   'كأس',
#   'امم',
#   'ورب',
#   'لكر',
#   'قدم',
#   '2024',
#   'مرة',
#   'سدس',
#   'فوز',
#   'كبر',
#   'لتف',
#   'اليوم',
#   'ضمن',
#   'جول',
#   'ثمن',
#   'شهد',
#   'أهل',
#   'سبن',
#   'عقب',
#   'فوز',
#   'ضيف',
#   'روج',
#   'رفع',
#   'نخب',
#   'ترك',
#   'رصد',
#   '16',
#   'نقط',
#   'صدر',
#   'جمع',
#   'تبق',
#   'برا',
#   'وحد',
#   'جمد',
#   'رصد',
#   'لتف',
#   'نقط',
#   'ركز',
#   'خمس',
#   'تفق',
#   'نخب',
#   'ترك',
#   'صدر',
#   'نخب',
#   'يلز',
#   'نجح',
#   'صعد',
#   'ركز',
#   'ثني',
#   'جمع',
#   'رصد',
#   '10',
#   'فوز',
#   'كرا',
#   'ركز',
#   'ثلث',
#   'رصد',
#   'نفس',
#   'ضمن',
#   'نفس',
#   'جول',
#   'ذات',
#   'قدم',
#   'نخب',
#   'ترك',
#   'صحب',
#   'لعب',
#   'طرق',
#   'ونس',
#   'اكغ',
#   'دقق',
#   'يضف',
#   'سين',
#   'توس',
#   'هدف',
#   'ثني',
#   'دقق',
#   'بين',
#   'اضف',
#   'كرم',
#   'اكتوركوغلو',
#   'هدف',
#   'ثلث',
#   'دقق',
#   '87',
#   'وفي',
#   'دقق',
#   'ثني',
#   'وقت',
#   'حسب',
#   'بدل',
#   'ضئع',
#   'شوط',
#   'ثني',
#   'سجل',
#   'سين',
#   'توس',
#   'هدف',
#   'ثني',
#   'ربع',
#   'لتر',
#   'حسم',
#   'سبن',
#   'بطق',
#   'الى',
#   'نهي',
#   '2024',
#   'صحب',
#   'وذل',
#   'بفز',
#   'ضيف',
#   'روج',
#   'جمع',
#   'ولى',
#   'دخل',
#   'فئز',
#   'لقب',
#   '3',
#   'رات',
#   'عوم',
#   '1964',
#   '2008',
#   'لقء',
#   'وهي',
#   'بحج',
#   'فوز',
#   'تضم',
#   'بطق',
#   'فوز',
#   'جول',
#   'اضة',
#   'اسكتلندا',
#   'تصدر',
#   'كانت',
#   'غئب',
#   'بحج',
#   'فوز',
#   'روخ',
#   'عدل',
#   'سلو',
#   'تضم',
#   'أهل',
#   'لفز',
#   'خمس',
#   'فرق',
#   'درب',
#   'لوس',
#   'دي',
#   'لحق',
#   'سبن',
#   'بأسكتلندا',
#   'صدر',
#   'ـ15',
#   'نقط',
#   '6',
#   'بري',
#   'لكل',
#   'وبت',
#   'نخب',
#   'تقدم',
#   'فرق',
#   '5',
#   'نقط',
#   'روج',
#   'ثلث',
#   'خضت',
#   'احد',
#   'برا',
#   'سبع',
#   'سمح',
#   'حسم',
#   'بطق',
#   'جمع',
#   'الى',
#   'نهي',
#   'أهل',
#   'بطل',
#   'وصف',
#   'جمع',
#   'عشر',
#   'نهي',
#   'قرر',
#   'صيف',
#   'قبل',
#   'ضمن',
#   'أهل',
#   'حسم',
#   'بطق',
#   'ثلث',
#   'خرى',
#   'عبر',
#   'لحق',
#   'دور',
#   'امم',
#   'ورب',
#   'تشر',
#   'جورج',
#   'نتج',
#   'صدر',
#   'جمع',
#   'ستى',
#   'ثلث',
#   'بطل',
#   'قري',
#   'وسم'],
#  '20200455_03_A.txt': ['نخب',
#   'غرب',
#   'سيد',
#   'عقد',
#   'درب',
#   'سبن',
#   'توج',
#   'كأس',
#   'علم',
#   'اعل',
#   'تحد',
#   'غرب',
#   'لكر',
#   'قدم',
#   'اليوم',
#   'خمس',
#   'عقد',
#   'درب',
#   'اسب',
#   'خورخ',
#   'يلد',
#   'قاد',
#   'بلد',
#   'فوز',
#   'كأس',
#   'علم',
#   'سيد',
#   'لكر',
#   'قدم',
#   'رال',
#   'قيد',
#   'نخب',
#   'نسي',
#   'خلف',
#   'رنس',
#   'رينالد',
#   'درس',
#   'نهء',
#   'همت',
#   'وقد',
#   'درس',
#   'نخب',
#   'غرب',
#   'سيد',
#   'أهل',
#   'ارخ',
#   'كأس',
#   'علم',
#   'صبح',
#   'نخب',
#   'عرب',
#   'أهل',
#   'لدر',
#   'ـ16',
#   'وجء',
#   'هاء',
#   'هام',
#   'درب',
#   'رنس',
#   'درب',
#   'لأولمبيك',
#   'لين',
#   'وتج',
#   'معه',
#   'لقب',
#   'دور',
#   'بطل',
#   'ورب',
#   'عقب',
#   'خسر',
#   'قسي',
#   'برا',
#   'ودي',
#   'زمب',
#   'غنى',
#   'تحد',
#   'اسب',
#   'اضي',
#   'خدم',
#   'يلد',
#   '42',
#   'عما',
#   'شكل',
#   'جلس',
#   'جدد',
#   'إدر',
#   'عقب',
#   'يقف',
#   'رئس',
#   'لوس',
#   'روبياليس',
#   'تحد',
#   'دول',
#   'فيف',
#   'سبب',
#   'فضح',
#   'قبل',
#   'أثر',
#   'روبياليس',
#   'عصف',
#   'جدل',
#   'بلد',
#   'خرج',
#   'لعب',
#   'جين',
#   'رموسو',
#   'عقب',
#   'فوز',
#   'سبن',
#   'جلتر',
#   'نهي',
#   'كأس',
#   'علم',
#   'سيد',
#   'سيد',
#   'أعل',
#   'تحد',
#   'اسب',
#   'تعي',
#   'درب',
#   'ونتس',
#   'توم',
#   'خلف',
#   'يلد',
#   'درب',
#   'نخب',
#   'وطن',
#   'سيد',
#   'بذل',
#   'صبح',
#   'مرأ',
#   'ولى',
#   'نصب',
#   'وكان',
#   'عبر',
#   'حلف',
#   'وثق',
#   'اشد',
#   'بدئ',
#   'امر',
#   'رفض',
#   'رئس',
#   'تحد',
#   'قال',
#   '25',
#   'لكن',
#   'صدر',
#   'وقت',
#   'لحق',
#   'بيا',
#   'يدن',
#   'صرف',
#   'روبياليس'],
#  '20200455_04_A.txt': ['اسأ',
#   'فرق',
#   'علم',
#   '20',
#   'عما',
#   'بدن',
#   'فوز',
#   'عدة',
#   'حقق',
#   'فرق',
#   'نخب',
#   'صغر',
#   'فجآ',
#   'فوز',
#   'فرق',
#   'كبر',
#   'حال',
#   'نخب',
#   'سان',
#   'حتل',
#   'ركز',
#   'اخر',
#   'صنف',
#   'فيف',
#   '207',
#   'ويع',
#   'اسأ',
#   'لسل',
#   'ارخ',
#   'كرة',
#   'قدم',
#   'ستى',
#   'نخب',
#   'وطن',
#   'حقق',
#   'فوز',
#   'طول',
#   'قرب',
#   '20',
#   'عما',
#   'بذل',
#   'حتل',
#   'نخب',
#   'سان',
#   'مارينو',
#   'ركز',
#   'اخر',
#   'صنف',
#   'تحد',
#   'دول',
#   'لكر',
#   'قدم',
#   'فيف',
#   'يعد',
#   '27',
#   '2004',
#   'سعد',
#   'يوم',
#   'ارخ',
#   'نخب',
#   'ورب',
#   'عند',
#   'تمك',
#   'فوز',
#   'صعب',
#   'ليختنشتا',
#   'برا',
#   'فوز',
#   'اخر',
#   'وحد',
#   'بعد',
#   'فوز',
#   'سجل',
#   'نخب',
#   'سان',
#   'مارينو',
#   'لسل',
#   'نتج',
#   'سلب',
#   'قيس',
#   'بلغ',
#   '133',
#   'برا',
#   'بدن',
#   'حقق',
#   'سجل',
#   'خلل',
#   '16',
#   'هدف',
#   'فقط',
#   'وكان',
#   'رمه',
#   'فتح',
#   'صرع',
#   'جمع',
#   'مني',
#   'ـ547',
#   'لقى',
#   '128',
#   'هزم',
#   'عدل',
#   '5',
#   'بري',
#   'فقط',
#   'أسس',
#   'تحد',
#   'كرة',
#   'قدم',
#   'سان',
#   'مارينو',
#   'عام',
#   'أخر',
#   'شكل',
#   'فرق',
#   'وطن',
#   'عام',
#   '1986',
#   'وكان',
#   'ظهر',
#   'لسن',
#   'مارينو',
#   'سبق',
#   'عرف',
#   'فيف',
#   'عام',
#   'برا',
#   'هزم',
#   'يسر',
#   'ضمن',
#   'تصف',
#   'ؤهل',
#   'كأس',
#   'امم',
#   'ورب',
#   'عام',
#   '1992',
#   'وفي',
#   '1993',
#   'حقق',
#   'نتج',
#   'سلب',
#   'تمك',
#   'عدل',
#   'بدن',
#   'هدف',
#   'ترك',
#   'تصف',
#   'ؤهل',
#   'كأس',
#   'علم',
#   '1994',
#   'ولي',
#   'تحد',
#   'حمل',
#   'سان',
#   'مارينو',
#   'رقم',
#   'قيس',
#   'نخب',
#   'ورب',
#   'لقى',
#   'كبر',
#   'عدد',
#   'هدف',
#   'برا',
#   'عند',
#   'خسر',
#   'لعب',
#   'لمن',
#   'حتل',
#   'نخب',
#   'سان',
#   'مارينو',
#   'ركز',
#   'اخر',
#   'بدن',
#   'نقط',
#   'جمع',
#   'ثمن',
#   'تصف',
#   'ؤهل',
#   'كأس',
#   'امم',
#   'ورب',
#   'خسر',
#   'بري',
#   'الس',
#   'خاض',
#   'وهذا',
#   'ريب',
#   'جمع',
#   'سلف',
#   '13',
#   'نقط',
#   'دانمار',
#   '13',
#   'نقط',
#   'لند',
#   '12',
#   'نقط',
#   'كازاخس',
#   '12',
#   'نقط',
#   'رلند',
#   'شمل',
#   '3',
#   'نقط',
#   'سان',
#   'مارينو',
#   'صفر',
#   'نقط',
#   'تتح',
#   'سبع',
#   'فرص',
#   'جدد',
#   'لعب',
#   'يوج',
#   'فيه',
#   'رلند',
#   'شمل',
#   'دانمار',
#   'وسن',
#   'مارينو',
#   'دول',
#   'صغر',
#   'تقع',
#   'جزر',
#   'تحط',
#   'يطل',
#   'تزد',
#   'سحت',
#   'قلل',
#   '61',
#   'كيلومترا',
#   'بلغ',
#   'عدد',
#   'سكن',
#   '30',
#   'نسم'],
#  '20200455_05_A.txt': ['نظم',
#   'مهد',
#   'قدم',
#   'عثم',
#   'نصر',
#   'ملاذكرد',
#   'صلح',
#   'دين',
#   'يفك',
#   'دول',
#   'عمق',
#   'فطم',
#   'عرف',
#   'اهم',
#   'زرء',
#   'صلح',
#   'يقد',
#   'تبع',
#   'جرب',
#   'زرء',
#   'صلح',
#   'ارخ',
#   'سلم',
#   'خلص',
#   'فاد',
#   'نصب',
#   'ؤسس',
#   'وزر',
#   'وصل',
#   'ذرت',
#   'صلح',
#   'فضل',
#   'رجل',
#   'وزر',
#   'صلح',
#   'دين',
#   'ايب',
#   'اخر',
#   'زرء',
#   'دول',
#   'فطم',
#   'عبر',
#   'وزر',
#   'تمت',
#   'صلح',
#   'دري',
#   'علم',
#   'جذر',
#   'قذت',
#   'علم',
#   'سلم',
#   'حقب',
#   'حسس',
#   'ولم',
#   'تزل',
#   'ثمر',
#   'يجب',
#   'ارخ',
#   'شهد',
#   'سوء',
#   'طقت',
#   'عرب',
#   'رقع',
#   'سلم',
#   'متد',
#   'اسا',
#   'سطى',
#   'بلق',
#   'نظم',
#   'ملك',
#   'ولى',
#   'وزر',
#   'فوض',
#   'دول',
#   'لجق',
#   'تخذ',
#   'عدد',
#   'دبر',
#   'علم',
#   'سيس',
#   'عسكر',
#   'ادت',
#   'نهي',
#   'تمك',
#   'ذهب',
#   'اصل',
#   'فرع',
#   'طول',
#   'سنة',
#   'خطة',
#   'صلح',
#   'حيئ',
#   'جرى',
#   'عمل',
#   'قتض',
#   'عدد',
#   'دول',
#   'دول',
#   'زنك',
#   'وصل',
#   'دول',
#   'ايب',
#   'دول',
#   'عثم',
#   'كانت',
#   'اخر',
#   'دول',
#   'سلم',
#   'جمع',
#   'ؤسس',
#   'وزر',
#   'فبالتأكيد',
#   'حضر',
#   'صور',
#   'صلح',
#   'دين',
#   'وزر',
#   'دول',
#   'فطم',
#   'نجح',
#   'طبق',
#   'سيس',
#   'نظم',
#   'ملك',
#   'عدل',
#   'قضي',
#   'ظرف',
#   'سيس',
#   'وسياقاته',
#   'تحر',
#   'برع',
#   'واج',
#   'موج',
#   'لاحق',
#   'ثور',
#   'ضاد',
#   'طئش',
#   'بطش',
#   'نظم',
#   'ملك',
#   'يدر',
#   'دول',
#   'خلف',
#   'سلط',
#   'فان',
#   'مصر',
#   'كانت',
#   'حين',
#   'كمل',
#   'قرن',
#   'بعي',
#   'ذهب',
#   'خلف',
#   'فطم',
#   'عضد',
#   'وزر',
#   'صلح',
#   'دين',
#   'حمل',
#   'ترك',
#   'تقف',
#   'دول',
#   'عمق',
#   'وجد',
#   'فطم',
#   'ثقف',
#   'إدر',
#   'امر',
#   'فكك',
#   'عمل',
#   'صعب',
#   'وقد',
#   'ستع',
#   'صلح',
#   'دين',
#   'أكفأ',
#   'أقدر',
#   'رجل',
#   'حقق',
#   'همة',
#   'ولئ',
#   'نظم',
#   'ملك',
#   'فرس',
#   'مثل',
#   'طرف',
#   'وسط',
#   'داع',
#   'وفق',
#   'جنس',
#   'عرب',
#   'خلف',
#   'ترك',
#   'سلط',
#   'صلح',
#   'دين',
#   'كرد',
#   'حلة',
#   'خير',
#   'مثل',
#   'عنصر',
#   'وكل',
#   'رجل',
#   'ولى',
#   'وزر',
#   'ظل',
#   'وجد',
#   'خلف',
#   'رمز',
#   'سلط',
#   'دخل',
#   'بيئ',
#   'تمر',
#   'قلقل',
#   'ذهب',
#   'فكر',
#   'تير',
#   'نقض',
#   'ذهب',
#   'وضم',
#   'دول',
#   'شسع',
#   'منه',
#   'قطب',
#   'رحا',
#   'هندس',
#   'غير',
#   'شمل',
#   'صلح',
#   'ؤسس'],
#  '20200455_06_A.txt': ['كتب',
#   'فطم',
#   'ملي',
#   'كتب',
#   'هرس',
#   'عنو',
#   'خزن',
#   'امي',
#   'قرطب',
#   '900',
#   'صفح',
#   'عرف',
#   'علم',
#   'كتب',
#   'حضر',
#   'سلم',
#   'عظم',
#   'خزن',
#   'كتب',
#   'سلم',
#   'خزن',
#   'خزن',
#   'خلفاء',
#   'عبس',
#   'فكان',
#   'كتب',
#   'كثر',
#   'يقم',
#   'خزن',
#   'خلفاء',
#   'فطم',
#   'وكانت',
#   'عظم',
#   'خزن',
#   'أكثر',
#   'جمع',
#   'كتب',
#   'نفس',
#   'خزن',
#   'خلفاء',
#   'بني',
#   'امة',
#   'وكانت',
#   'خزن',
#   'كتب',
#   'نص',
#   'نفس',
#   'ورد',
#   'شهب',
#   'دين',
#   'كتب',
#   'صنع',
#   'انش',
#   'تحدث',
#   'فضء',
#   'سيس',
#   'نافس',
#   'شرع',
#   'خلف',
#   'مثل',
#   'عبر',
#   'وظف',
#   'سعي',
#   'حفظ',
#   'علم',
#   'عني',
#   'فكان',
#   'ميد',
#   'نفس',
#   'سبق',
#   'قمة',
#   'كتب',
#   'ركز',
#   'حرص',
#   'دول',
#   'ثلث',
#   'شائ',
#   'لتك',
#   'ثقف',
#   'يسد',
#   'دخل',
#   'زدهار',
#   'عمر',
#   'تطر',
#   'عكس',
#   'مدى',
#   'وفئ',
#   'زما',
#   'ميد',
#   'خدم',
#   'علم',
#   'إجلال',
#   'علماء',
#   'قلد',
#   'شاء',
#   'كتب',
#   'حضر',
#   'سلم',
#   'ثمر',
#   'سار',
#   'عرف',
#   'طول',
#   'بدأ',
#   'عمل',
#   'جمع',
#   'قرآ',
#   'عظم',
#   'كثر',
#   'تلا',
#   'روي',
#   'حاديث',
#   'وحل',
#   'اصل',
#   'عرف',
#   'فرع',
#   'علم',
#   'بطن',
#   'كتب',
#   'حفظ',
#   'ضمو',
#   'يسر',
#   'دول',
#   'كثر',
#   'كتب',
#   'شتى',
#   'كتب',
#   'نزل',
#   'علماء',
#   'مرء',
#   'فقد',
#   'كانت',
#   'عني',
#   'خلفاء',
#   'رشد',
#   'قرآ',
#   'لهم',
#   'خلفاء',
#   'سلط',
#   'بأن',
#   'صنع',
#   'كتب',
#   'إنشاء',
#   'كتب',
#   'دخل',
#   'ضمن',
#   'ولو',
#   'وظف',
#   'سلط',
#   'أحد',
#   'تمم',
#   'شرع',
#   'حكم',
#   'سيس',
#   'وصف',
#   'كتب',
#   'نتج',
#   'لتل',
#   'رعي',
#   'ثمر',
#   'حرك',
#   'عرف',
#   'زمن',
#   'رشد',
#   'ولارتباط',
#   'كتب',
#   'عمة',
#   'سلط',
#   'صرت',
#   'ضرب',
#   'مثل',
#   'كانت',
#   'عدة',
#   'ضخم',
#   'فقد',
#   'وصف',
#   'قرئ',
#   'صحب',
#   'كتب',
#   'كبر',
#   'بأن',
#   'صحب',
#   'خزن',
#   'كذل',
#   'حال',
#   'رجل',
#   'دول',
#   'تنفذ',
#   'قدر',
#   'سيس',
#   'حدث',
#   'ارخ',
#   'بأن',
#   'ورء',
#   'كثر',
#   'عظماء',
#   'سسة',
#   'زرء',
#   'مثل',
#   'وزر',
#   'بوه',
#   'صحب',
#   'ابن',
#   'ملك',
#   'كتب',
#   'ضخم',
#   'شمل',
#   'مئت',
#   'وست',
#   'الف',
#   'جلد',
#   'حسب',
#   'جاء',
#   'ذكر',
#   'يقت',
#   'حمي',
#   'عجم',
#   'دبء',
#   'قنى',
#   'ادب',
#   'فضل',
#   'شار',
#   'كتب',
#   'سلط',
#   'صلح',
#   'دين',
#   'ايب',
#   'كتب',
#   'يعط',
#   'طبع',
#   'بلغ',
#   'دلل',
#   'سمت',
#   'رجل',
#   'تنفذ',
#   'عصر',
#   'زهر',
#   'حضر',
#   'عرب',
#   'سلم',
#   'ولم',
#   'غفل',
#   'سلط',
#   'صلح',
#   'دين',
#   'تنب',
#   'اثر',
#   'علم',
#   'لهذ',
#   'كتب',
#   'حية',
#   'سيس',
#   'إيجاز',
#   'بلغ',
#   'قئل',
#   'بلد',
#   'قلم',
#   'فضل',
#   'وفق',
#   'ؤرخ',
#   'ابن',
#   'نجم',
#   'زهر',
#   'لوك',
#   'مصر',
#   'قهر'],
#  '20200455_07_A.txt': ['حرب',
#   'جبه',
#   'سيبرانية',
#   '35',
#   'فرق',
#   'قرص',
#   'حرب',
#   'أجل',
#   'لسط',
#   'وقت',
#   'بكر',
#   'يوم',
#   'سبت',
#   'سبع',
#   'حبس',
#   'علم',
#   'فاس',
#   'رقب',
#   'حدث',
#   'سحة',
#   'شنت',
#   'حرك',
#   'قام',
#   'سلم',
#   'حمس',
#   'عمل',
#   'طوف',
#   'قصى',
#   'وهي',
#   'وسع',
#   'عمل',
#   'هدف',
#   'حلل',
#   'اسرائيلي',
#   '5',
#   'عقد',
#   'جنب',
#   'اكد',
#   'دول',
#   'حلل',
#   'قتل',
#   'حمس',
#   'عبر',
#   'جرأ',
#   'رضي',
#   'وطن',
#   'غلف',
#   'غزة',
#   'خضع',
#   'يطر',
#   'فجر',
#   'سمء',
#   'صواريخ',
#   'عرض',
#   'وسع',
#   'لعب',
#   'نري',
#   'وجه',
#   'طوف',
#   'سرع',
#   'رائيل',
#   'لرد',
#   'عبر',
#   'طلق',
#   'بـ',
#   'عمل',
#   'سيف',
#   'حدد',
#   'وبن',
#   'اعل',
#   'دول',
#   'حلل',
#   'حلة',
#   'سرع',
#   'عدد',
#   'دول',
#   'غرب',
#   'اعل',
#   'وفي',
#   'حجم',
#   'عظم',
#   'وقف',
#   'رسم',
#   'عرب',
#   'أيد',
#   'لسط',
#   'كانت',
#   'فئة',
#   'بعن',
#   'سعد',
#   'قتل',
#   'جنب',
#   'قام',
#   'لسط',
#   'طرق',
#   'هؤلاء',
#   'جمع',
#   'نشط',
#   'يبر',
#   'برز',
#   'جمع',
#   'جمع',
#   'تسلل',
#   'روس',
#   'شهر',
#   'عرف',
#   'بسم',
#   'كيل',
#   'Killnet',
#   'كثف',
#   'هجم',
#   'ضد',
#   'ؤسس',
#   'اسرائيلية',
#   'ردا',
#   'حرب',
#   'وضع',
#   'لبن',
#   'عرك',
#   'وزي',
#   'لسط',
#   'حلل',
#   'تدر',
#   'فضء',
#   'فرض',
#   'وفي',
#   'يوم',
#   'احد',
#   'ثمن',
#   'وقع',
#   'حكم',
#   'اسرائيلية',
#   'رسم',
#   'تاح',
#   'وصل',
#   'ستى',
#   'أعل',
#   'كيل',
#   'فور',
#   'سؤل',
#   'هجم',
#   'كترو',
#   'عبر',
#   'طبق',
#   'غرم',
#   'كسب',
#   'كيل',
#   'وهي',
#   'جمع',
#   'ؤيد',
#   'لرس',
#   'نشط',
#   'ثني',
#   '2022',
#   'فضل',
#   'هجم',
#   'حرم',
#   'خدم',
#   'DDoS',
#   'واصل',
#   'شنت',
#   'ضد',
#   'وكر',
#   'وخص',
#   'دول',
#   'دلع',
#   'حرب',
#   'روس',
#   'اوكرانية',
#   'ربع',
#   'اول',
#   'عام',
#   'اضي',
#   'يؤد',
#   'نوع',
#   'هجم',
#   'الكترونية',
#   'غرق',
#   'خدم',
#   'وقع',
#   'ويب',
#   'هدف',
#   'بطف',
#   'طلب',
#   'تصل',
#   'حزم',
#   'تصل',
#   'احا',
#   'الف',
#   'نتج',
#   'أثر',
#   'قدر',
#   'بطء',
#   'نظم',
#   'ضعف',
#   'بشد',
#   'منع',
#   'وصل',
#   'الي'],
#  '20200455_08_A.txt': ['امم',
#   'ابن',
#   'حزم',
#   'رئس',
#   'زرء',
#   'دلس',
#   'شرف',
#   'ضيع',
#   'شرع',
#   'فكر',
#   '80',
#   'صفح',
#   'ذهب',
#   'نشر',
#   'بدء',
#   'امر',
#   'ريس',
#   'سلط',
#   'ذهب',
#   'ابي',
#   'حنف',
#   'فإن',
#   'قضة',
#   'وسف',
#   'كانت',
#   'قضة',
#   'فكان',
#   'قضء',
#   'بلد',
#   'قصى',
#   'شرق',
#   'قصى',
#   'عمل',
#   'فرق',
#   'ونس',
#   'صحب',
#   'نتم',
#   'ذهب',
#   'حنف',
#   'ذهب',
#   'الك',
#   'بن',
#   'انس',
#   'عند',
#   'دلس',
#   'يحى',
#   'بن',
#   'يحى',
#   'ليث',
#   'سلط',
#   'قبل',
#   'قول',
#   'فكان',
#   'يلي',
#   'قطر',
#   'شور',
#   'يشر',
#   'أصحاب',
#   'ذهب',
#   'لنص',
#   'ثمن',
#   'يهد',
#   'فقه',
#   'عظم',
#   'امم',
#   'ابن',
#   'حزم',
#   'ظهر',
#   'دلس',
#   'ؤرخ',
#   'حرك',
#   'نشر',
#   'ذهب',
#   'يلف',
#   'ظار',
#   'زاي',
#   'وهي',
#   'علق',
#   'نشر',
#   'ذهب',
#   'بقة',
#   'دفع',
#   'طرح',
#   'طلب',
#   'عرف',
#   'وفئ',
#   'قوة',
#   'قصد',
#   'سيس',
#   'رسو',
#   'نصع',
#   'ناس',
#   'وإن',
#   'ميز',
#   'تتح',
#   'رمز',
#   'ذهب',
#   'حين',
#   'تحز',
#   'مقاليد',
#   'سلط',
#   'تسد',
#   'تشريعاته',
#   'نشر',
#   'علم',
#   'قتد',
#   'ناس',
#   'صحح',
#   'انه',
#   'خلف',
#   'يقف',
#   'حكم',
#   'وهذا',
#   'امر',
#   'وجد',
#   'اليوم',
#   'عرق',
#   'اهم',
#   'وقع',
#   'نزل',
#   'حكم',
#   'تزم',
#   'ناس',
#   'سلط',
#   'قضء',
#   'سبب',
#   'حور',
#   'يكن',
#   'شيع',
#   'ذهب',
#   'كثر',
#   'ذيع',
#   'رسخ',
#   'فعل',
#   'صدر',
#   'طبع',
#   'شرع',
#   'قبل',
#   'قضء',
#   'وليس',
#   'جرد',
#   'وصي',
#   'فقه',
#   'جهز',
#   'سلط',
#   'نفذ',
#   'فكر',
#   'حور',
#   'رصد',
#   'فقه',
#   'وزر',
#   'فإن',
#   'يدر',
#   'نزل',
#   'بين',
#   'وبين',
#   'خصم',
#   'قهء',
#   'تكون',
#   'عدل',
#   'دمت',
#   'رعي',
#   'سيس',
#   'تحط',
#   'ذهب',
#   'الك',
#   'نفس',
#   'ذهب',
#   'أصحاب',
#   'ظهر',
#   'دلس',
#   'وقد',
#   'فهم',
#   'صدر',
#   'فكر',
#   'ابن',
#   'حزم',
#   'وصف',
#   'عمق',
#   'فكر',
#   'درك',
#   'ارخ',
#   'فكر',
#   'ذهب',
#   'لأن',
#   'لحظ',
#   'رجل',
#   'دول',
#   'قرب',
#   'قمة',
#   'سلط',
#   'بلط',
#   'امي',
#   'سبر',
#   'خبا',
#   'زوا',
#   'سلط',
#   'سيس',
#   'ايم',
#   'قلب',
#   'يدر',
#   'يفل',
#   'ذهب',
#   'ظهر',
#   'لقى',
#   'ذيع',
#   'دلس',
#   'لكن',
#   'خفت',
#   'ورب',
#   'يكون',
#   'سبب',
#   'خفت',
#   'خفء',
#   'تبع',
#   'يزة',
#   'نصب',
#   'قضء',
#   'كتف',
#   'درس',
#   'ألف'],
#  '20200455_09_A.txt': ['قتل',
#   'طفل',
#   'لسط',
#   'عمر',
#   '6',
#   'سنو',
#   'ـ26',
#   'طعن',
#   'امر',
#   'قلت',
#   'شرط',
#   'امر',
#   'رجل',
#   'ولي',
#   'ينو',
#   'طعن',
#   'طفل',
#   'مسل',
#   '26',
#   'طعن',
#   'أرد',
#   'اصب',
#   'دته',
#   'جرح',
#   'ردد',
#   'عبر',
#   'عدي',
#   'سلم',
#   'لسط',
#   'تهم',
#   'شرط',
#   'رجل',
#   '71',
#   'عما',
#   'ركب',
#   'جرم',
#   'كره',
#   'ضد',
#   'طفل',
#   '6',
#   'سنو',
#   'وأم',
#   '32',
#   'عما',
#   'قئل',
#   'ضحي',
#   'استهدفتا',
#   'سبب',
#   'عقد',
#   'سيق',
#   'حرب',
#   'تخض',
#   'رائيل',
#   'لسط',
#   'وقل',
#   'قئد',
#   'شرط',
#   'قطع',
#   'ويل',
#   'بين',
#   'نشر',
#   'وقع',
#   'وصل',
#   'جمع',
#   'تمك',
#   'حقق',
#   'حدد',
#   'ضحي',
#   'هجم',
#   'وحش',
#   'كنت',
#   'هدف',
#   'شبه',
#   'سبب',
#   'كون',
#   'سلم',
#   'صرع',
#   'دئر',
#   'شرق',
#   'وسط',
#   'حمس',
#   'اسرائيلي',
#   'عثر',
#   'ضبط',
#   'ضحي',
#   'وقت',
#   'تأخر',
#   'يوم',
#   'سبت',
#   'نزل',
#   'بلد',
#   'حلي',
#   '65',
#   'كيلومترا',
#   'جنب',
#   'غرب',
#   'شيكاغو',
#   'وقل',
#   'كتب',
#   'قئد',
#   'شرط',
#   'صبي',
#   'اعل',
#   'وفت',
#   'عرض',
#   'طعن',
#   '26',
#   'مرة',
#   'بسك',
#   'عسكر',
#   'حسب',
#   'جاء',
#   'شرح',
#   'جثة',
#   'يوم',
#   'احد',
#   'أصب',
#   'رأة',
#   'أكثر',
#   '12',
#   'طعن',
#   'وبق',
#   'شفى',
#   'يوم',
#   'حلت',
#   'قرة',
#   'وفي',
#   'رسل',
#   'نصة',
#   'لأم',
#   'ولد',
#   'جاء',
#   'شبه',
#   'صرخ',
#   'قئل',
#   'يجب',
#   'تمت',
#   'عمل',
#   'حسب',
#   'ورد',
#   'جلس',
#   'علق',
#   'امر',
#   'سلم',
#   'كير',
#   'قال',
#   'كير',
#   'ضحي',
#   'يعش',
#   'طبق',
#   'ارض',
#   'نزل',
#   'شبه',
#   'الك',
#   'نزل',
#   'وقل',
#   'شرط',
#   'تم',
#   'عثر',
#   'رجل',
#   'شبه',
#   'ركب',
#   'جرم',
#   'يوم',
#   'سبت',
#   'جلس',
#   'خرج',
#   'ارض',
#   'قرب',
#   'ممر',
#   'نزل',
#   'صبا',
#   'جرح',
#   'ودع',
#   'شرط',
#   'حبس',
#   'نظر',
#   'ثول',
#   'حكم',
#   'وجه',
#   'رجل',
#   'تهم',
#   'قتل',
#   'درج',
#   'حال',
#   'قتل',
#   'درج',
#   'تهم',
#   'ركب',
#   'جرم',
#   'ضرب',
#   'شدد',
#   'سلح',
#   'فتك',
#   'ولم',
#   'نشر',
#   'سلط',
#   'سمء',
#   'كتب',
#   'شيكاغو',
#   'جلس',
#   'علق',
#   'امر',
#   'سلم',
#   'خطط',
#   'عقد',
#   'ؤمر',
#   'صحف',
#   'يوم',
#   'احد',
#   'فرد',
#   'اسر',
#   'حدد',
#   'هوة',
#   'ودع',
#   'صبي',
#   'امر',
#   'اصل',
#   'ولد',
#   'حنن',
#   'شاه'],
#  '20200455_10_A.txt': ['شار',
#   'امن',
#   'قوم',
#   'امر',
#   'بعد',
#   'دخل',
#   'اير',
#   'صعد',
#   'نزع',
#   'شرق',
#   'وسط',
#   'حذر',
#   'شار',
#   'امن',
#   'قوم',
#   'امر',
#   'جيك',
#   'ولف',
#   'حمل',
#   'صعد',
#   'صرع',
#   'شرق',
#   'ولم',
#   'بعد',
#   'دخل',
#   'اير',
#   'شدد',
#   'عدة',
#   'امر',
#   'حجز',
#   'غزة',
#   'ولو',
#   'شنط',
#   'وقل',
#   'ولف',
#   'صرح',
#   'علم',
#   'امر',
#   'اليوم',
#   'شنط',
#   'تمل',
#   'علم',
#   'دقق',
#   'بشأ',
#   'اما',
#   'وجد',
#   'امر',
#   'حجز',
#   'قام',
#   'لكن',
#   'اكد',
#   'عدت',
#   'ولو',
#   'نسب',
#   'إدر',
#   'رئس',
#   'جو',
#   'بيد',
#   'أشر',
#   'سؤل',
#   'امر',
#   'بلد',
#   'دخل',
#   'خطط',
#   'عسكر',
#   'ولك',
#   'ؤكد',
#   'علن',
#   'وفي',
#   'حدث',
#   'خصة',
#   'لزم',
#   'بقو',
#   'حرب',
#   'وقل',
#   'شنط',
#   'ركز',
#   'ضمن',
#   'وفر',
#   'غذء',
#   'ياه',
#   'دوء',
#   'أوى',
#   'سكن',
#   'ذكر',
#   'غلب',
#   'عظمى',
#   'سكن',
#   'قطع',
#   'غزة',
#   'علق',
#   'بحر',
#   'قام',
#   'سلم',
#   'حمس',
#   'سحق',
#   'كرم',
#   'سلم',
#   'حد',
#   'عبر',
#   'وفي',
#   'علق',
#   'حمل',
#   'تطر',
#   'قال',
#   'ولف',
#   'خطر',
#   'قائ',
#   'صعد',
#   'نزع',
#   'عبر',
#   'فتح',
#   'جبه',
#   'خرى',
#   'طبع',
#   'دخل',
#   'اير',
#   'شدد',
#   'ولي',
#   'تحد',
#   'يمك',
#   'بعد',
#   'فرض',
#   'تخذ',
#   'اير',
#   'قرر',
#   'دخل',
#   'بشر',
#   'بصر',
#   'خرى',
#   'تبع',
#   'خطر',
#   'درك',
#   'بدي',
#   'ضيف',
#   'لذا',
#   'تحر',
#   'رئس',
#   'سرع',
#   'شكل',
#   'حزم',
#   'نشر',
#   'حمل',
#   'طئر',
#   'شرق',
#   'توسط',
#   'ؤكد',
#   'خطة',
#   'بعث',
#   'رسل',
#   'ردع',
#   'وضح',
#   'طرف',
#   'حول',
#   'غلل',
#   'عبر',
#   'أعل',
#   'وزر',
#   'دفع',
#   'امر',
#   'لود',
#   'اوس',
#   'سبت',
#   'رسل',
#   'حمل',
#   'طئر',
#   'خرى',
#   'شرق',
#   'توسط',
#   'بغة',
#   'ردع',
#   'عمل',
#   'عدي',
#   'ضد',
#   'رائيل',
#   'جهد',
#   'يرم',
#   'وسع',
#   'نطق',
#   'حرب',
#   'نضم',
#   'حمل',
#   'طئر',
#   'ديت',
#   'ايزنهاور',
#   'جمع',
#   'سفن',
#   'رفق',
#   'حمل',
#   'طئر',
#   'جيرالد',
#   'ورد',
#   'رسل',
#   'شنط',
#   'نطق',
#   'عقب',
#   'عمل',
#   'طوف',
#   'قصى',
#   'طلق',
#   'قام',
#   'فلسطينية',
#   'ضد',
#   'رائيل',
#   '7',
#   'اول',
#   'جري',
#   'اكد',
#   'تحدث',
#   'بسم',
#   'جلس',
#   'امن',
#   'قوم',
#   'بيت',
#   'ابض',
#   'جون',
#   'كيرب',
#   'اليوم',
#   'احد',
#   'قلق',
#   'ولي',
#   'تحد',
#   'حيل',
#   'نزع'],
#  '20200455_11_A.txt': ['امر',
#   'طلق',
#   'جسر',
#   'جوا',
#   'نقل',
#   'واد',
#   'غثة',
#   'مصر',
#   'طلق',
#   'دين',
#   'علم',
#   'خدم',
#   'سان',
#   'دبي',
#   'جسر',
#   'جوا',
#   'نقل',
#   'واد',
#   'غثة',
#   'طرئ',
#   'مصر',
#   'ولب',
#   'خلف',
#   'صعد',
#   'ازم',
#   'حسب',
#   'ذكر',
#   'وكل',
#   'وام',
#   'دين',
#   'خدم',
#   'سان',
#   'دبي',
#   'طلق',
#   'جسر',
#   'جوا',
#   'نقل',
#   'واد',
#   'غثة',
#   'مصر',
#   'ولب',
#   'ازم',
#   'تتصاعدالحرب',
#   'غزة',
#   'يوم',
#   'تسع',
#   'لحظ',
#   'لحظ',
#   'غار',
#   'عنف',
#   'رفع',
#   'عدد',
#   'قتلى',
#   'جيش',
#   'اسرائيلي',
#   'أكد',
#   'وكل',
#   'قرر',
#   'جاء',
#   'جهز',
#   'وجه',
#   'تحد',
#   'زايد',
#   'فرض',
#   'ازم',
#   'طرئ',
#   'نطق',
#   'وذل',
#   'ندء',
#   'طرئ',
#   'نظم',
#   'صحة',
#   'رنمج',
#   'غذي',
#   'نظم',
#   'امم',
#   'تحد',
#   'طفل',
#   'يسف',
#   'وقل',
#   'جوسيب',
#   'دير',
#   'نفذ',
#   'دين',
#   'علم',
#   'خدم',
#   'سان',
#   'دبي',
#   'قمن',
#   'إطلاق',
#   'جسر',
#   'جوي',
#   'انس',
#   'شكل',
#   'عجل',
#   'نقل',
#   'مدد',
#   'غثة',
#   'لحة',
#   'تأثر',
#   'فقم',
#   'ازم',
#   'عكس',
#   'جهد',
#   'روح',
#   'تعا',
#   'اوق',
#   'نزع',
#   'حجة',
#   'لحة',
#   'تفد',
#   'دين',
#   'شبك',
#   'وسع',
#   'ورد',
#   'عزز',
#   'جهد',
#   'سان',
#   'دعم',
#   'جاب',
#   'سرع',
#   'ازم',
#   'رفع',
#   'ستى',
#   'جهز',
#   'حال',
#   'وبالتالي',
#   'قاذ',
#   'روح',
#   'برئ',
#   'أكد',
#   'وكل',
#   'انه',
#   'اليوم',
#   'دبي',
#   'طار',
#   'عرش',
#   'صري',
#   'غثي',
#   'ولى',
#   'مخز',
#   'رنمج',
#   'غذي',
#   'علم',
#   'يسف',
#   '11',
#   'لزم',
#   'ياه',
#   'نظف',
#   'شخص',
#   'ضفة',
#   'مدد',
#   'حيي',
#   'حفظ',
#   'كرم',
#   'تضرر',
#   'وفر',
#   'واد',
#   'غذي',
#   'سسي',
#   'عزز',
#   'شكل',
#   'كبر',
#   'قدر',
#   'جاب',
#   'صحة',
#   'خلل',
#   'هلل',
#   'حمر',
#   'صري',
#   'يضم',
#   'جهز',
#   'جمع',
#   'واج',
#   'حيج',
#   'لحة',
#   'نشئ',
#   'ازم',
#   'ضفة',
#   'خفف',
#   'أثر',
#   'نقص',
#   'غذء',
#   'شخص',
#   'يجه',
#   'ظرف',
#   'صعب'],
#  '20200455_12_A.txt': ['مصر',
#   'رفع',
#   'درج',
#   'عدد',
#   'شفي',
#   'حسب',
#   'تطر',
#   'ازم',
#   'غزة',
#   'وجه',
#   'وزر',
#   'صحة',
#   'سكن',
#   'صري',
#   'خلد',
#   'عبد',
#   'غفر',
#   'رفع',
#   'درج',
#   'عدد',
#   'نفذ',
#   'لتج',
#   'رئس',
#   'عبد',
#   'فتح',
#   'سيس',
#   'بشأ',
#   'دعي',
#   'ازم',
#   'قطع',
#   'غزة',
#   'عقد',
#   'عبد',
#   'غفر',
#   'جمع',
#   'يدو',
#   'كلء',
#   'وزر',
#   'رؤساء',
#   'غرف',
#   'حفظ',
#   'قهر',
#   'جيز',
#   'شمل',
#   'ينء',
#   'سوس',
#   'اسماعيلية',
#   'وبورسعيد',
#   'دمياط',
#   'شرق',
#   'وجء',
#   'نفذ',
#   'لتج',
#   'سيس',
#   'خلل',
#   'جمع',
#   'جلس',
#   'امن',
#   'تبع',
#   'عدد',
#   'نظم',
#   'صحة',
#   'عمل',
#   'طرئ',
#   'طبة',
#   'دعي',
#   'حدث',
#   'قطع',
#   'رفع',
#   'جهز',
#   'شفي',
#   'حلة',
#   'حفظ',
#   'وفر',
#   'كفة',
#   'لزم',
#   'دوي',
#   'أكياس',
#   'لدم',
#   'أوضح',
#   'تحدث',
#   'رسم',
#   'وزر',
#   'صحة',
#   'سكن',
#   'حسم',
#   'عبد',
#   'وزر',
#   'سمع',
#   'عرض',
#   'بشأ',
#   'حار',
#   'خطة',
#   'تضم',
#   'قدم',
#   'خدم',
#   'علج',
#   'سوء',
#   'جرح',
#   'خصص',
#   'علج',
#   'اصب',
#   'كسر',
#   'حال',
#   'طبة',
#   'رصد',
#   'مرض',
#   'زمن',
#   'ضغط',
#   'سكر',
#   'فشل',
#   'كلي',
#   'جنب',
#   'خدم',
#   'خلل',
#   'رصد',
#   'مرض',
#   'عدة',
#   'علج',
#   'وفر',
#   'طعم',
#   'مصل',
#   'لزم',
#   'شير',
#   'رفع',
#   'درج',
#   'عدد',
#   'سشف',
#   'حفظ',
#   'وقل',
#   'عبد',
#   'غفر',
#   'وزر',
#   'طمأ',
#   'وفر',
#   'مخز',
#   'دوي',
#   'لزم',
#   'أسطو',
#   'كسج',
#   'أكياس',
#   'لدم',
#   'طمأ',
#   'جهز',
#   'شفي',
#   'قوى',
#   'بشر',
#   'كفة',
#   'نسق',
#   'شفي',
#   'جمع',
#   'حال',
#   'حيج',
#   'دعم',
#   'طقم',
#   'طبة',
#   'أضف',
#   'تحدث',
#   'وزر',
#   'وجه',
#   'وضع',
#   'شفى',
#   'سبق',
#   'جهز',
#   'اهب',
#   'جهز',
#   'بكف',
#   'جهز',
#   'بحث',
#   'عمل',
#   'كنقط',
#   'ركز',
#   'وقع',
#   'يتم',
#   'خلل',
#   'فرز',
#   'حال',
#   'وتج',
#   'سشف',
#   'وفق',
#   'طبع',
#   'قدم',
#   'خدم',
#   'طبة',
#   'ضيف',
#   'خطة',
#   'تضم',
#   'دفع',
#   'عدد',
#   'عيد',
#   'تنقل',
#   'عمل',
#   'حال',
#   'خفف',
#   'ضغط',
#   'شفي',
#   'حلة'],
#  '20200455_13_A.txt': ['هاميل',
#   'حقق',
#   'فوز',
#   'رقم',
#   '100',
#   'رمل',
#   '1',
#   'حقق',
#   'برط',
#   'لوس',
#   'هاميل',
#   'فوز',
#   'رقم',
#   '100',
#   'بطل',
#   'علم',
#   'رمل',
#   'فوز',
#   'بجز',
#   'روس',
#   'كبرى',
#   'أصبح',
#   'هاميل',
#   'سئق',
#   'ارخ',
#   'حقق',
#   '100',
#   'فوز',
#   'رمل',
#   'سطر',
#   'الم',
#   'ايكل',
#   'شوماخر',
#   'حقق',
#   '91',
#   'يعد',
#   'هاميل',
#   'فضل',
#   'سئق',
#   'ارخ',
#   'رمل',
#   'وقد',
#   'حقق',
#   'عدد',
#   'جاز',
#   'فرد',
#   'جمع',
#   'خلل',
#   'سير',
#   'احترافية',
#   'وفز',
#   'هاميل',
#   'سبع',
#   'بطل',
#   'علم',
#   'سئق',
#   'ارخ',
#   'فاز',
#   'هاميل',
#   'بـ',
#   '103',
#   'سبق',
#   'رمل',
#   'سئق',
#   'سبق',
#   'ارخ',
#   'شوماخر'],
#  '20200455_14_A.txt': ['نوم',
#   'وسك',
#   'تفز',
#   'لقب',
#   'رال',
#   'فتح',
#   'توج',
#   'ياب',
#   'نوم',
#   'وسك',
#   'لقب',
#   'بطل',
#   'رال',
#   'فتح',
#   'بفز',
#   'امر',
#   'جينيفر',
#   'برد',
#   'برا',
#   'نهي',
#   'نتج',
#   'وهذا',
#   'لقب',
#   'ربع',
#   'لأس',
#   'بطل',
#   'جرند',
#   'رقم',
#   'قيس',
#   'جدد',
#   'اعب',
#   'ياب',
#   'انه',
#   'صغر',
#   'لعب',
#   'تفز',
#   'أربع',
#   'لقب',
#   'بطل',
#   'جرند',
#   'سلم',
#   'لمن',
#   'شتف',
#   'حقق',
#   'عام',
#   '1988',
#   'تعد',
#   'لحظ',
#   'ارخ',
#   'سعى',
#   'وصل',
#   'سير',
#   'نجح',
#   'علم',
#   'تنس'],
#  '20200455_15_A.txt': ['كريستيانو',
#   'رونالدو',
#   'نضم',
#   'نصر',
#   'سعد',
#   'اعل',
#   'ندي',
#   'نصر',
#   'سعد',
#   'لكر',
#   'قدم',
#   'ضمم',
#   'نجم',
#   'رتغال',
#   'كريستيانو',
#   'رونالدو',
#   'صفف',
#   'صفق',
#   'نقل',
#   'حر',
#   'وقع',
#   'رونالدو',
#   'لمد',
#   'عام',
#   'ندي',
#   'رتد',
#   'رقم',
#   '7',
#   'يعد',
#   'رونالدو',
#   'فضل',
#   'لعب',
#   'وقد',
#   'حقق',
#   'عدد',
#   'جاز',
#   'فرد',
#   'جمع',
#   'خلل',
#   'سير',
#   'احترافية',
#   'وفز',
#   'رونالدو',
#   'خمس',
#   'كرت',
#   'لعب',
#   'ارخ',
#   'فاز',
#   'رونالدو',
#   'بدر',
#   'بطل',
#   'ورب',
#   'ندي',
#   'مانشستر',
#   'يتد',
#   'ريل',
#   'درد',
#   'ويوفنتوس',
#   'نضم',
#   'رونالدو',
#   'نصر',
#   'فسخ',
#   'عقد',
#   'ندي',
#   'مانشستر',
#   'يتد',
#   'اضي',
#   'وكان',
#   'رونالدو',
#   'نضم',
#   'مانشستر',
#   'يتد',
#   '12',
#   'غدر',
#   'ندي',
#   'جلز',
#   'ضمم',
#   'درد',
#   'أمل',
#   'نصر',
#   'سعد',
#   'رونالدو',
#   'فرق',
#   'حقق',
#   'زيد',
#   'نجح',
#   'سنو',
#   'قبل'],
#  '20200455_16_A.txt': ['ملك',
#   'عبد',
#   'الل',
#   'ثني',
#   'دعو',
#   'تعا',
#   'قلم',
#   'واج',
#   'تحد',
#   'خطب',
#   'وجه',
#   'امة',
#   'يوم',
#   'دعا',
#   'ملك',
#   'عبد',
#   'الل',
#   'ثني',
#   'ملك',
#   'ارد',
#   'تعا',
#   'قلم',
#   'كبر',
#   'واج',
#   'تحد',
#   'وجه',
#   'شرق',
#   'وسط',
#   'وقل',
#   'نطق',
#   'وجه',
#   'لحظ',
#   'حرج',
#   'وأن',
#   'ضرر',
#   'عمل',
#   'دول',
#   'إيجاد',
#   'حلل',
#   'شكل',
#   'شرك',
#   'ذكر',
#   'ملك',
#   'وجه',
#   'حدد',
#   'حجة',
#   'تعا',
#   'قضا',
#   'امن',
#   'ياه',
#   'طقة',
#   'وقل',
#   'كله',
#   'تحد',
#   'وجد',
#   'يمكن',
#   'علج',
#   'خلل',
#   'جهد',
#   'جمع',
#   'تأت',
#   'دعة',
#   'ملك',
#   'عبد',
#   'الل',
#   'تعا',
#   'خضم',
#   'فتر',
#   'وتر',
#   'زايد',
#   'نطق',
#   'ادت',
#   'حرب',
#   'مرة',
#   'وكر',
#   'فقم',
#   'نقص',
#   'علم',
#   'غذء',
#   'وهن',
#   'خاف',
#   'بشأ',
#   'حمل',
#   'دلع',
#   'صرع',
#   'وسع'],
#  '20200455_17_A.txt': ['امستردام',
#   'عصم',
#   'هولند',
#   'إحدى',
#   'كبر',
#   'عبر',
#   'وحد',
#   'جمل',
#   'أكثر',
#   'مدن',
#   'جذب',
#   'ورب',
#   'بشب',
#   'قنا',
#   'رئع',
#   'جسر',
#   'سحر',
#   'والتي',
#   'كسب',
#   'لقب',
#   'فسج',
#   'ورب',
#   'تمز',
#   'دين',
#   'علم',
#   'ثقف',
#   'ارخ',
#   'تحف',
#   'ريجكس',
#   'وبت',
#   'اني',
#   'فرن',
#   'تضم',
#   'جمع',
#   'تنع',
#   'قهي',
#   'طعم',
#   'محل',
#   'جرة',
#   'ئجر',
#   'زور',
#   'درج',
#   'لاستكشاف',
#   'دين',
#   'تضف',
#   'امستردام',
#   'عدد',
#   'فعل',
#   'ثقف',
#   'هرج',
#   'طول',
#   'عام',
#   'عبر',
#   'دين',
#   'لاستكشاف',
#   'الف',
#   'ثقف',
#   'جمل',
#   'طبع',
#   'هولند'],
#  '20200455_18_A.txt': ['ارج',
#   'تفز',
#   'كأس',
#   'علم',
#   '2022',
#   'فزت',
#   'ارج',
#   'كأس',
#   'علم',
#   '2022',
#   'غلب',
#   'رازيل',
#   'برا',
#   'نهي',
#   'ركل',
#   'رجح',
#   'نهء',
#   'وقت',
#   'اصل',
#   'ضفي',
#   'عدل',
#   'وهذ',
#   'مرة',
#   'ثلث',
#   'تفز',
#   'ارج',
#   'كأس',
#   'فوز',
#   'لقب',
#   'عمي',
#   '1978',
#   '1986',
#   'وكان',
#   'ونل',
#   'يسي',
#   'نجم',
#   'ارج',
#   'برز',
#   'حصل',
#   'جئز',
#   'فضل',
#   'لعب',
#   'بطل',
#   'سجل',
#   'يسي',
#   'هدف',
#   'صنع',
#   'هدف',
#   'خرى',
#   'تعد',
#   'مرة',
#   'ولى',
#   'تفز',
#   'ارج',
#   'كأس',
#   'علم',
#   'عام',
#   '1986'],
#  '20200455_19_A.txt': ['ولي',
#   'تحد',
#   'ارد',
#   'وقع',
#   'تفق',
#   'عزز',
#   'تعا',
#   'عسكر',
#   'وقع',
#   'ولي',
#   'تحد',
#   'ارد',
#   'تفق',
#   'عزز',
#   'تعا',
#   'عسكر',
#   'بلد',
#   'وفر',
#   'تفق',
#   'وقع',
#   'وزر',
#   'خرج',
#   'امر',
#   'نتو',
#   'بلن',
#   'وزر',
#   'خرج',
#   'ارد',
#   'ايم',
#   'صفد',
#   'ارد',
#   '470',
#   'ملي',
#   'كمساعد',
#   'عسكر',
#   'مدى',
#   'سنو',
#   'خمس',
#   'قبل',
#   'تفق',
#   'علم',
#   'علق',
#   'قوة',
#   'ولي',
#   'تحد',
#   'ارد',
#   'لطل',
#   'كانت',
#   'دول',
#   'ولي',
#   'تحد',
#   'ورد',
#   'رئس',
#   'سعد',
#   'عسكر',
#   'ارد',
#   'سعد',
#   'تفق',
#   'ارد',
#   'حدث',
#   'جيش',
#   'علج',
#   'تحد',
#   'مني',
#   'يجه',
#   'شكل',
#   'فضل',
#   'شمل',
#   'تحد',
#   'هدد',
#   'رهب',
#   'جمع',
#   'صرع',
#   'سمر',
#   'سور',
#   'تفق',
#   'تطر',
#   'رحب',
#   'يعد',
#   'ولي',
#   'تحد',
#   'شرق',
#   'وسط'],
#  '20200455_20_A.txt': ['بتر',
#   'دين',
#   'ثري',
#   'ارخ',
#   'تقع',
#   'وهي',
#   'حفر',
#   'صخر',
#   'جبل',
#   'ورد',
#   'رمل',
#   'أسس',
#   'دين',
#   'عصر',
#   'وكانت',
#   'سار',
#   'جار',
#   'قدم',
#   'بتر',
#   'شهر',
#   'عبد',
#   'قبر',
#   'لون',
#   'عقد',
#   'نحت',
#   'أبراج',
#   'شهر',
#   'خزن',
#   'يقو',
#   'خزن',
#   'رعو',
#   'مثل',
#   'بتر',
#   'اليوم',
#   'ترث',
#   'علم',
#   'سكو',
#   'عبر',
#   'وحد',
#   'اهم',
#   'وجه',
#   'سيح',
#   'يأت',
#   'زور',
#   'لاستكشاف',
#   'وقع',
#   'سحر',
#   'عرف',
#   'ارخ',
#   'ثقف',
#   'فرد'],
#  '20200455_21_A.txt': ['كور',
#   'شمل',
#   'تجر',
#   'جرب',
#   'صرخ',
#   'جدد',
#   'اجر',
#   'كور',
#   'شمل',
#   'جرب',
#   'صرخ',
#   'جدد',
#   'عقب',
#   'دول',
#   'فرض',
#   'عليها',
#   'أعل',
#   'وكل',
#   'باء',
#   'كور',
#   'شمل',
#   'جرب',
#   'اجر',
#   'نجح',
#   'وأن',
#   'صرخ',
#   'قدر',
#   'حمل',
#   'رأس',
#   'نوي',
#   'تعد',
#   'جرب',
#   'صرخ',
#   'حدث',
#   'لسل',
#   'جرب',
#   'اجر',
#   'كور',
#   'شمل',
#   'شهر',
#   'خير',
#   'وقد',
#   'ثرت',
#   'جرب',
#   'خاف',
#   'بشأ',
#   'رنمج',
#   'سلح',
#   'نوي',
#   'لكر',
#   'شمل',
#   'ندد',
#   'ولي',
#   'تحد',
#   'وكر',
#   'جنب',
#   'جرب',
#   'صرخ',
#   'كور',
#   'شمل',
#   'ودع',
#   'ونغ',
#   'ينغ',
#   'وقف',
#   'جرب',
#   'صرخ',
#   'عود',
#   'حدث',
#   'نوي'],
#  '20200455_22_A.txt': ['لوفيغارو',
#   'شرط',
#   'رنس',
#   'تدا',
#   'تكس',
#   'حمس',
#   'هدد',
#   'إغلاق',
#   'حدث',
#   'هدد',
#   'شرط',
#   'رنس',
#   'بـ',
#   'غلق',
#   'طعم',
#   'تكس',
#   'دين',
#   'لنس',
#   'جنب',
#   'سبب',
#   'عطل',
#   'نظم',
#   'ضءة',
#   'ينر',
#   'حرف',
#   'اسم',
#   'بدو',
#   'نظم',
#   'ضءة',
#   'ينر',
#   'حرف',
#   'اول',
#   'سي',
#   'C',
#   'اصب',
#   'فلم',
#   'ظهر',
#   'نظر',
#   'اسم',
#   'HAMAS',
#   'ضاء',
#   'ليل',
#   'دفع',
#   'وضع',
#   'بعض',
#   'سكن',
#   'تصل',
#   'شرط',
#   'إبلاغ',
#   'وجد',
#   'لفت',
#   'دعم',
#   'حرك',
#   'قام',
#   'سلم',
#   'حمس',
#   'ظل',
#   'عدو',
#   'اسرائيلي',
#   'سمر',
#   'غزة',
#   'أضف',
#   'صحف',
#   'لوفيغارو',
#   'رنس',
#   'سلط',
#   'بدر',
#   'قدم',
#   'طعم',
#   'هدد',
#   'صحب',
#   'غلق',
#   'صلح',
#   'نظم',
#   'ضءة',
#   'حرف',
#   'سي',
#   'ظهر',
#   'اسم',
#   'كمل',
#   'وقد',
#   'اثر',
#   'حدث',
#   'سخر',
#   'رود',
#   'وقع',
#   'وصل',
#   'دول',
#   'قطع',
#   'يدو',
#   'ظهر',
#   'فعل',
#   'شرط',
#   'كشف',
#   'حدث',
#   'حسس',
#   'سلط',
#   'رنس',
#   'علق',
#   'قام',
#   'جرد',
#   'حدث',
#   'عرض',
#   'عكس',
#   'حدث',
#   'حلة',
#   'شنج',
#   'خوف',
#   'تسد',
#   'رنس',
#   'ظل',
#   'رار',
#   'عدو',
#   'اسرائيلي',
#   'غز'],
#  '20200455_23_A.txt': ['سور',
#   'صين',
#   'عظم',
#   'لسل',
#   'حصن',
#   'مدى',
#   'قرن',
#   'لحم',
#   'صين',
#   'غزة',
#   'كبر',
#   'أكثر',
#   'عمل',
#   'هندس',
#   'ثرة',
#   'عجب',
#   'ارخ',
#   'متد',
#   'هيكل',
#   'ضخم',
#   'آلف',
#   'ميل',
#   'عبر',
#   'نظر',
#   'طبع',
#   'صين',
#   'تضم',
#   'مثل',
#   'سور',
#   'صين',
#   'عظم',
#   'برز',
#   'علم',
#   'ثقف',
#   'صين',
#   'جذب',
#   'سيح',
#   'شهر',
#   'اليوم',
#   'كوج',
#   'سيح',
#   'زور',
#   'خلف',
#   'حاء',
#   'علم',
#   'ماع',
#   'بمشاهدته',
#   'واستكشاف',
#   'ارخ',
#   'عرق'],
#  '20200455_24_A.txt': ['اشو',
#   'تشو',
#   'دين',
#   'انك',
#   'قدم',
#   'وجد',
#   'جبل',
#   'ديز',
#   'يرو',
#   'تم',
#   'بنؤ',
#   'قرن',
#   'خمس',
#   'وتم',
#   'تخل',
#   'عنه',
#   'وقت',
#   'لحق',
#   'قرن',
#   'سدس',
#   'كشف',
#   'جدد',
#   'عام',
#   '1911',
#   'بسط',
#   'امر',
#   'هيرام',
#   'أصبح',
#   'حين',
#   'وحد',
#   'اهم',
#   'وقع',
#   'ترث',
#   'علم',
#   'سكو',
#   'وجه',
#   'سيح',
#   'شهر',
#   'شهر',
#   'اشو',
#   'تشو',
#   'ببن',
#   'هندس',
#   'رئع',
#   'جمل',
#   'نظر',
#   'طبع',
#   'عبر',
#   'فهم',
#   'حضر',
#   'انك',
#   'قدم',
#   'ارخ',
#   'جذب',
#   'زور',
#   'حاء',
#   'علم',
#   'ماع',
#   'جمل',
#   'ارخ',
#   'فرد']}

# %% [markdown]
# ### 3. Data Splitting (train, and test)

# %%
english_data = list(english_results.values())
english_labels = labeled_dataset['Class'][:24].tolist()
arabic_data = list(arabic_results.values())
arabic_labels = labeled_dataset['Class'][24:].tolist()

all_data = english_data + arabic_data
all_labels = english_labels + arabic_labels

X_train, X_test, y_train, y_test = train_test_split(
    all_data, all_labels, test_size=0.2, random_state=42
)

# %% [markdown]
# ### 4. Text Vectorization

# %%
train_docs = [' '.join(words) for words in X_train]
test_docs = [' '.join(words) for words in X_test]

tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(train_docs)
X_test_tfidf = tfidf_vectorizer.transform(test_docs)

# %%
train_docs
# Out:
# ['presid push gun safeti hunter biden mount second amend defens hunter biden tuesday plung burgeon second amend fight whether govern disarm peopl use illeg drug lawyer presid son repeatedli said defend three feder gun charg argu main feder law charg unconstitut light recent suprem court rule argument stand stark contrast presid joe biden advocaci stricter gun law hunter biden arraign wilmington tuesday legal team formal signal intent mount constitut challeng charg accus biden possess gun drug user lie feder form bought biden plead guilti arraign decad feder gun control act ban drug user possess gun 2022 suprem court dramat expand second amend right way obfusc rule gun restrict valid resembl gun law exist found era rule new york state rifl pistol associ bruen teed host conflict rule close today gun law must hew late 1700 prohibit among gun restrict face new challeng bruen defend argu law bar peopl carri firearm intox simpli becom intox past hunter biden head trial next year becom famou defend far lean second amend even father expect make gun safeti focu reelect campaign sinc take offic presid taken slew execut action work bipartisan coalit congress pass first gun legisl law nearli three decad toughen background check young gun buyer help state implement red flag law keep firearm domest violenc offend presid took step last month announc feder offic gun violenc prevent',
#  'europ hold late usa comeback regain ryder cup europ surviv sunday scare regain ryder cup hold late us fightback win rome suffer record defeat whistl strait 2021 host made feroci start marco simon golf club maintain pace take command point lead final day singl match yet move within half point win threshold insid open six game wait ensu visitor accumul flurri win keep dream first away triumph 30 year aliv europ rise anxieti final quell england tommi fleetwood face ricki fowler penultim match struck sensat tee shot help take 16th hole guarante least tie singl match consequ ryder cup confirm spark euphor scene among team europ tear captain luke donald long process amaz journey emot donald said tv interview stress usa put fight today realli hat proud 12 guy form bond day one gave everyth ryder cup special guy play share memori brief interlud close match finish crowd flood onto cours surround 18th green republ ireland shane lowri play undoubtedli enjoy lost hole career tie jordan spieth',
#  'histor theater england claim found bard surviv stage william shakespear famous wrote world stage offici theater norfolk england claim found surviv stage bard perform recent restor board discov layer floor georg guildhal king lynn unit kingdom oldest work theater larg oak board almost 30 centimet 12 inch wide 15 centimet 6 inch thick held togeth wooden peg instead nail tim fitzhigham guildhal creativ director tell new york time derrick bryson taylor discoveri realli realli excit pretti archaeologist jonathan clark expert mediev build lead research studi wooden board two month tri date floor examin construct method use build well growth ring seen surviv wood base detail say floorboard date earli 15th centuri like 1417 1430 fitzhigham claim shakespear must perform document show bard act venu late 16th centuri accord bbc news colin paterson borough account book record borough paid shakespear compani come play venu say sinc floorboard instal long 1590 like surfac shakespear walk clark tell bbc news end hall perform took place',
#  'ملك عبد الل ثني دعو تعا قلم واج تحد خطب وجه امة يوم دعا ملك عبد الل ثني ملك ارد تعا قلم كبر واج تحد وجه شرق وسط وقل نطق وجه لحظ حرج وأن ضرر عمل دول إيجاد حلل شكل شرك ذكر ملك وجه حدد حجة تعا قضا امن ياه طقة وقل كله تحد وجد يمكن علج خلل جهد جمع تأت دعة ملك عبد الل تعا خضم فتر وتر زايد نطق ادت حرب مرة وكر فقم نقص علم غذء وهن خاف بشأ حمل دلع صرع وسع',
#  'شار امن قوم امر بعد دخل اير صعد نزع شرق وسط حذر شار امن قوم امر جيك ولف حمل صعد صرع شرق ولم بعد دخل اير شدد عدة امر حجز غزة ولو شنط وقل ولف صرح علم امر اليوم شنط تمل علم دقق بشأ اما وجد امر حجز قام لكن اكد عدت ولو نسب إدر رئس جو بيد أشر سؤل امر بلد دخل خطط عسكر ولك ؤكد علن وفي حدث خصة لزم بقو حرب وقل شنط ركز ضمن وفر غذء ياه دوء أوى سكن ذكر غلب عظمى سكن قطع غزة علق بحر قام سلم حمس سحق كرم سلم حد عبر وفي علق حمل تطر قال ولف خطر قائ صعد نزع عبر فتح جبه خرى طبع دخل اير شدد ولي تحد يمك بعد فرض تخذ اير قرر دخل بشر بصر خرى تبع خطر درك بدي ضيف لذا تحر رئس سرع شكل حزم نشر حمل طئر شرق توسط ؤكد خطة بعث رسل ردع وضح طرف حول غلل عبر أعل وزر دفع امر لود اوس سبت رسل حمل طئر خرى شرق توسط بغة ردع عمل عدي ضد رائيل جهد يرم وسع نطق حرب نضم حمل طئر ديت ايزنهاور جمع سفن رفق حمل طئر جيرالد ورد رسل شنط نطق عقب عمل طوف قصى طلق قام فلسطينية ضد رائيل 7 اول جري اكد تحدث بسم جلس امن قوم بيت ابض جون كيرب اليوم احد قلق ولي تحد حيل نزع',
#  'archaeologist uncov vast ancient megac petén jungl guatemala megac believ inhabit maya civil estim time old remain megac includ conglomer tabernacl palac discoveri slip new light maya civil impact mesoamerica megac discov use fashion call lidar use spotlight collud face earth lidar data reveal outlin megac hidden thick jungl cover archaeologist sinc begun dig point uncov number vestig includ crockeri obsidian blade wanton jewelri discoveri ancient megac major discoveri archaeologist largest maya megac discov guatemala recent decad furnish new percept maya civil archaeologist believ megac formerli major center power commerc hope farther excav reveal histori cultur',
#  'unit kingdom face polit crisi brexit uk vote leav european union 2016 govern unabl agre deal eu exit led great deal uncertainti divis uk brexit crisi also neg impact uk economi valu pound fallen declin invest crisi also led rise hate crime xenophobia',
#  'لوفيغارو شرط رنس تدا تكس حمس هدد إغلاق حدث هدد شرط رنس بـ غلق طعم تكس دين لنس جنب سبب عطل نظم ضءة ينر حرف اسم بدو نظم ضءة ينر حرف اول سي C اصب فلم ظهر نظر اسم HAMAS ضاء ليل دفع وضع بعض سكن تصل شرط إبلاغ وجد لفت دعم حرك قام سلم حمس ظل عدو اسرائيلي سمر غزة أضف صحف لوفيغارو رنس سلط بدر قدم طعم هدد صحب غلق صلح نظم ضءة حرف سي ظهر اسم كمل وقد اثر حدث سخر رود وقع وصل دول قطع يدو ظهر فعل شرط كشف حدث حسس سلط رنس علق قام جرد حدث عرض عكس حدث حلة شنج خوف تسد رنس ظل رار عدو اسرائيلي غز',
#  'esport electron sport competit videotap game play profession gamer esport come major onlook sport million peopl watch event event onlin esport assidu grow fleetli estim worth billion bone esport particularli popular among youth peopl seen way connect musket contend other around world rise esport reflect chang natur entertain esport form digit entertain consum onlin way',
#  'protest new york call new york cri free palestin rang new york friday thousand protest took street denounc isra bomb gaza strip call end isra occup liber palestinian territori protest took multipl block citi serv crossroad religion nation span world larg youth protest drew demonstr origin sport palestinian flag keffiyeh accus israel genocid call us withdraw support middl eastern alli thousand attempt flee southern gaza israel warn evacu expect ground offens extrem worri stop said liz zacharia professor attend march settler coloni project israel end said zacharia whose father jerusalem ad feed grow cycl violenc oppress palestinian river sea palestin free protest chant multipl protest brooklyn dozen protest arrest friday night held block traffic demonstr front home senat major leader chuck schumer democrat plan travel congression deleg israel call organis jewish voic peac urg elect offici stop genocid palestinian gaza protest drew mass protest front strong polic presenc arrest includ two elect offici rabbi descend holocaust survivor 200 demonstr also gather southern us citi miami heavi polic presenc guard protest made sure keep distanc dozen demonstr across street ana amireh 51 businessman son palestinian immigr said respond kill innoc israel anoth genocid gaza strip crimin war wrong',
#  'colosseum ancient theater center megac rome itali erect concret graveston largest theater ever erect consid one topmost workshop roman armatur engin colosseum ellipt shape 188 measur long 156 measur wide wall 57 measur high arena 86 measur long 54 measur wide colosseum could hold estim observ colosseum use confront contest beast hunt public prosecut also use religi observ carniv colosseum one popular sightseer lodeston rome unesco world heritag site symbol roman empir one icon mileston world',
#  'كتب فطم ملي كتب هرس عنو خزن امي قرطب 900 صفح عرف علم كتب حضر سلم عظم خزن كتب سلم خزن خزن خلفاء عبس فكان كتب كثر يقم خزن خلفاء فطم وكانت عظم خزن أكثر جمع كتب نفس خزن خلفاء بني امة وكانت خزن كتب نص نفس ورد شهب دين كتب صنع انش تحدث فضء سيس نافس شرع خلف مثل عبر وظف سعي حفظ علم عني فكان ميد نفس سبق قمة كتب ركز حرص دول ثلث شائ لتك ثقف يسد دخل زدهار عمر تطر عكس مدى وفئ زما ميد خدم علم إجلال علماء قلد شاء كتب حضر سلم ثمر سار عرف طول بدأ عمل جمع قرآ عظم كثر تلا روي حاديث وحل اصل عرف فرع علم بطن كتب حفظ ضمو يسر دول كثر كتب شتى كتب نزل علماء مرء فقد كانت عني خلفاء رشد قرآ لهم خلفاء سلط بأن صنع كتب إنشاء كتب دخل ضمن ولو وظف سلط أحد تمم شرع حكم سيس وصف كتب نتج لتل رعي ثمر حرك عرف زمن رشد ولارتباط كتب عمة سلط صرت ضرب مثل كانت عدة ضخم فقد وصف قرئ صحب كتب كبر بأن صحب خزن كذل حال رجل دول تنفذ قدر سيس حدث ارخ بأن ورء كثر عظماء سسة زرء مثل وزر بوه صحب ابن ملك كتب ضخم شمل مئت وست الف جلد حسب جاء ذكر يقت حمي عجم دبء قنى ادب فضل شار كتب سلط صلح دين ايب كتب يعط طبع بلغ دلل سمت رجل تنفذ عصر زهر حضر عرب سلم ولم غفل سلط صلح دين تنب اثر علم لهذ كتب حية سيس إيجاز بلغ قئل بلد قلم فضل وفق ؤرخ ابن نجم زهر لوك مصر قهر',
#  'قتل طفل لسط عمر 6 سنو ـ26 طعن امر قلت شرط امر رجل ولي ينو طعن طفل مسل 26 طعن أرد اصب دته جرح ردد عبر عدي سلم لسط تهم شرط رجل 71 عما ركب جرم كره ضد طفل 6 سنو وأم 32 عما قئل ضحي استهدفتا سبب عقد سيق حرب تخض رائيل لسط وقل قئد شرط قطع ويل بين نشر وقع وصل جمع تمك حقق حدد ضحي هجم وحش كنت هدف شبه سبب كون سلم صرع دئر شرق وسط حمس اسرائيلي عثر ضبط ضحي وقت تأخر يوم سبت نزل بلد حلي 65 كيلومترا جنب غرب شيكاغو وقل كتب قئد شرط صبي اعل وفت عرض طعن 26 مرة بسك عسكر حسب جاء شرح جثة يوم احد أصب رأة أكثر 12 طعن وبق شفى يوم حلت قرة وفي رسل نصة لأم ولد جاء شبه صرخ قئل يجب تمت عمل حسب ورد جلس علق امر سلم كير قال كير ضحي يعش طبق ارض نزل شبه الك نزل وقل شرط تم عثر رجل شبه ركب جرم يوم سبت جلس خرج ارض قرب ممر نزل صبا جرح ودع شرط حبس نظر ثول حكم وجه رجل تهم قتل درج حال قتل درج تهم ركب جرم ضرب شدد سلح فتك ولم نشر سلط سمء كتب شيكاغو جلس علق امر سلم خطط عقد ؤمر صحف يوم احد فرد اسر حدد هوة ودع صبي امر اصل ولد حنن شاه',
#  'سور صين عظم لسل حصن مدى قرن لحم صين غزة كبر أكثر عمل هندس ثرة عجب ارخ متد هيكل ضخم آلف ميل عبر نظر طبع صين تضم مثل سور صين عظم برز علم ثقف صين جذب سيح شهر اليوم كوج سيح زور خلف حاء علم ماع بمشاهدته واستكشاف ارخ عرق',
#  'us open women semifin coco gauff madison key lead american quest home glori fan might rememb specif take place recent two took court three week ago final western southern open cincinnati gauff win straight set claim biggest titl career victori ohio came midst gauff best period form blossom tenni career momentum continu us open american recent outing flush meadow anoth impress perform beat jelena ostapenko eas 10th victori row somewhat tournament gauff look like seriou contend win maiden grand slam titl insist get ahead still lot tenni left play gauff said still mindset begin tournament would think close end right mental told still anoth two week play right feel emot fresh think problem past grand slam would emot muchová much seen underdog gauff despit also show excel form recent rise rank 10 world czech lost final french open earlier year drop one set en rout semifin continu extraordinari comeback season suffer seri injuri last year threaten career',
#  'امم ابن حزم رئس زرء دلس شرف ضيع شرع فكر 80 صفح ذهب نشر بدء امر ريس سلط ذهب ابي حنف فإن قضة وسف كانت قضة فكان قضء بلد قصى شرق قصى عمل فرق ونس صحب نتم ذهب حنف ذهب الك بن انس عند دلس يحى بن يحى ليث سلط قبل قول فكان يلي قطر شور يشر أصحاب ذهب لنص ثمن يهد فقه عظم امم ابن حزم ظهر دلس ؤرخ حرك نشر ذهب يلف ظار زاي وهي علق نشر ذهب بقة دفع طرح طلب عرف وفئ قوة قصد سيس رسو نصع ناس وإن ميز تتح رمز ذهب حين تحز مقاليد سلط تسد تشريعاته نشر علم قتد ناس صحح انه خلف يقف حكم وهذا امر وجد اليوم عرق اهم وقع نزل حكم تزم ناس سلط قضء سبب حور يكن شيع ذهب كثر ذيع رسخ فعل صدر طبع شرع قبل قضء وليس جرد وصي فقه جهز سلط نفذ فكر حور رصد فقه وزر فإن يدر نزل بين وبين خصم قهء تكون عدل دمت رعي سيس تحط ذهب الك نفس ذهب أصحاب ظهر دلس وقد فهم صدر فكر ابن حزم وصف عمق فكر درك ارخ فكر ذهب لأن لحظ رجل دول قرب قمة سلط بلط امي سبر خبا زوا سلط سيس ايم قلب يدر يفل ذهب ظهر لقى ذيع دلس لكن خفت ورب يكون سبب خفت خفء تبع يزة نصب قضء كتف درس ألف',
#  'حرب جبه سيبرانية 35 فرق قرص حرب أجل لسط وقت بكر يوم سبت سبع حبس علم فاس رقب حدث سحة شنت حرك قام سلم حمس عمل طوف قصى وهي وسع عمل هدف حلل اسرائيلي 5 عقد جنب اكد دول حلل قتل حمس عبر جرأ رضي وطن غلف غزة خضع يطر فجر سمء صواريخ عرض وسع لعب نري وجه طوف سرع رائيل لرد عبر طلق بـ عمل سيف حدد وبن اعل دول حلل حلة سرع عدد دول غرب اعل وفي حجم عظم وقف رسم عرب أيد لسط كانت فئة بعن سعد قتل جنب قام لسط طرق هؤلاء جمع نشط يبر برز جمع جمع تسلل روس شهر عرف بسم كيل Killnet كثف هجم ضد ؤسس اسرائيلية ردا حرب وضع لبن عرك وزي لسط حلل تدر فضء فرض وفي يوم احد ثمن وقع حكم اسرائيلية رسم تاح وصل ستى أعل كيل فور سؤل هجم كترو عبر طبق غرم كسب كيل وهي جمع ؤيد لرس نشط ثني 2022 فضل هجم حرم خدم DDoS واصل شنت ضد وكر وخص دول دلع حرب روس اوكرانية ربع اول عام اضي يؤد نوع هجم الكترونية غرق خدم وقع ويب هدف بطف طلب تصل حزم تصل احا الف نتج أثر قدر بطء نظم ضعف بشد منع وصل الي',
#  'alexand grew ancient greek kingdom macedonia conquer persian empir alexand great stand one icon militari leader histori 336 bce age 20 succeed father philip ii king greek kingdom macedonia began seri aggress militari campaign secur territori alreadi expand rule eastward king alexand success conquer first persian empir extend macedonia territori far pakistan india campaign spread greek cultur across middl east boost develop hellenist cultur death 323 bce alexand militari career stand mani victori even forc sever outnumb historian also note reportedli alway insist lead troop front line battl result sustain numer seriou cleaver slash head sword gash thigh catapult missil lodg shoulder arrow pierc lung allegedli almost kill alexand signific battl plu one sieg last effect environ still observ today greek thebe confus egyptian citi thebe revolt macedonian rule alexand march troop put revolut win alexand first major macedonian conqueror proceed torch citi paul cartledg professor emeritu greek cultur univers cambridg say one reason alexand burn thebe warn greek rebel macedonian rule strategi quit work sparta revolt albeit unsuccess 331 bce time alexand asia take persian empir',
#  'jordan field hospit gaza await vital suppli jordanian field hospit gaza despit recent inabl provid medic servic due difficult circumst continu oper current locat strip prime minist bisher khasawneh said sunday militari field hospit maintain presenc gaza approxim two decad dedic staff prepar resum servic soon receiv necessari medic suppli current inaccess said note demonstr jordan commit provid assist relief peopl gaza express kingdom reject forc displac prime minist emphasis forc displac popul clear red line jordan broader arab region note action regard war crime intern law primari object halt ongo aggress militari oper enabl establish humanitarian aid corridor reviv polit solut said sinc begin attack civilian gaza majesti king abdullah activ work coordin intern effort aim stop escal flagrant aggress civilian gaza ad point majesti current visit four european capit london rome berlin pari highlight king commun world leader recent day aim ensur immedi implement intern humanitarian law uphold share humanitarian valu safeguard innoc civilian khasawneh highlight polit solut aim end conflict within framework solut lead establish independ fulli sovereign palestinian state base june 4 1967 line east jerusalem capit sole solut ensur peac region stabil highlight jordan effort provid humanitarian assist palestinian gaza strip said majesti king abdullah issu direct dispatch essenti aid note immedi respons call first humanitarian aid plane jordan land el arish airport egypt supervis royal jordanian air forc',
#  'امر طلق جسر جوا نقل واد غثة مصر طلق دين علم خدم سان دبي جسر جوا نقل واد غثة طرئ مصر ولب خلف صعد ازم حسب ذكر وكل وام دين خدم سان دبي طلق جسر جوا نقل واد غثة مصر ولب ازم تتصاعدالحرب غزة يوم تسع لحظ لحظ غار عنف رفع عدد قتلى جيش اسرائيلي أكد وكل قرر جاء جهز وجه تحد زايد فرض ازم طرئ نطق وذل ندء طرئ نظم صحة رنمج غذي نظم امم تحد طفل يسف وقل جوسيب دير نفذ دين علم خدم سان دبي قمن إطلاق جسر جوي انس شكل عجل نقل مدد غثة لحة تأثر فقم ازم عكس جهد روح تعا اوق نزع حجة لحة تفد دين شبك وسع ورد عزز جهد سان دعم جاب سرع ازم رفع ستى جهز حال وبالتالي قاذ روح برئ أكد وكل انه اليوم دبي طار عرش صري غثي ولى مخز رنمج غذي علم يسف 11 لزم ياه نظف شخص ضفة مدد حيي حفظ كرم تضرر وفر واد غذي سسي عزز شكل كبر قدر جاب صحة خلل هلل حمر صري يضم جهز جمع واج حيج لحة نشئ ازم ضفة خفف أثر نقص غذء شخص يجه ظرف صعب',
#  'olymp swim test event sein cancel due poor water qualiti swim competit suppos serv test event ahead 2024 pari olymp cancel due poor water qualiti sein cast doubt french govern audaci plan clean famou river next summer world aquat intern govern bodi swim water sport pari 2024 organ committe said rainfal juli left sein pollut swim decis cancel event open water swim world cup made world aquat consult french swim feder ffn public health author world aquat disappoint water qualiti sein result cancel world aquat open water swim world cup health athlet must alway top prioriti said world aquat presid husain olymp organ express confid sein would better prepar swimmer game open next year pari 2024 organ committe statement new infrastructur put place improv water treatment raini weather start pari olymp conting measur postpon competit due water qualiti also plan pari plan make river sein centerpiec olymp featur promin open ceremoni sever swim event paratriathlon triathlon event set take place water clean effort underway sinc 2018 two disinfect unit wastewat treatment plant run pari region public sanit servic oper summer structur help improv water qualiti rainwat storag basin construct',
#  'كور شمل تجر جرب صرخ جدد اجر كور شمل جرب صرخ جدد عقب دول فرض عليها أعل وكل باء كور شمل جرب اجر نجح وأن صرخ قدر حمل رأس نوي تعد جرب صرخ حدث لسل جرب اجر كور شمل شهر خير وقد ثرت جرب خاف بشأ رنمج سلح نوي لكر شمل ندد ولي تحد وكر جنب جرب صرخ كور شمل ودع ونغ ينغ وقف جرب صرخ عود حدث نوي',
#  'unit state china engag trade war signific impact countri war began 2018 trump administr assess tariff chines good china redress tariff us good war escal sinc also unclear end trade war neg impact husbandri countri also led increas pressur two countri war also signific impact global trade',
#  'india beat pakistan cricket world cup sport rivalri like fan pack insid enorm narendra modi stadium ahmedabad india watch india take pakistan icc men cricket world cup saturday front sea blue india shirt punctuat flash green orang white peopl wave india flag home team secur thump victori pakistan often describ one greatest sport grudg match world cricket match alway bound geopolit faultlin separ two nation small pocket pakistan fan incred difficult travel india due red tape histor mistrust restrict movement citizen countri larg absent crowd pakistan head coach mickey arthur said afterward per reuter event seem like bilater seri rather world cup hear dil dil pakistan countri unoffici anthem come microphon ye play role go use excus us live moment next ball go combat indian player tonight ad two team play seven year indian soil pakistan never defeat india men world cup initi seem record might threat pakistan began strongli en rout set competit total captain babar azam mohammad rizwan put 82 run third wicket babar score first time odi match india',
#  'هاميل حقق فوز رقم 100 رمل 1 حقق برط لوس هاميل فوز رقم 100 بطل علم رمل فوز بجز روس كبرى أصبح هاميل سئق ارخ حقق 100 فوز رمل سطر الم ايكل شوماخر حقق 91 يعد هاميل فضل سئق ارخ رمل وقد حقق عدد جاز فرد جمع خلل سير احترافية وفز هاميل سبع بطل علم سئق ارخ فاز هاميل بـ 103 سبق رمل سئق سبق ارخ شوماخر',
#  'مصر رفع درج عدد شفي حسب تطر ازم غزة وجه وزر صحة سكن صري خلد عبد غفر رفع درج عدد نفذ لتج رئس عبد فتح سيس بشأ دعي ازم قطع غزة عقد عبد غفر جمع يدو كلء وزر رؤساء غرف حفظ قهر جيز شمل ينء سوس اسماعيلية وبورسعيد دمياط شرق وجء نفذ لتج سيس خلل جمع جلس امن تبع عدد نظم صحة عمل طرئ طبة دعي حدث قطع رفع جهز شفي حلة حفظ وفر كفة لزم دوي أكياس لدم أوضح تحدث رسم وزر صحة سكن حسم عبد وزر سمع عرض بشأ حار خطة تضم قدم خدم علج سوء جرح خصص علج اصب كسر حال طبة رصد مرض زمن ضغط سكر فشل كلي جنب خدم خلل رصد مرض عدة علج وفر طعم مصل لزم شير رفع درج عدد سشف حفظ وقل عبد غفر وزر طمأ وفر مخز دوي لزم أسطو كسج أكياس لدم طمأ جهز شفي قوى بشر كفة نسق شفي جمع حال حيج دعم طقم طبة أضف تحدث وزر وجه وضع شفى سبق جهز اهب جهز بكف جهز بحث عمل كنقط ركز وقع يتم خلل فرز حال وتج سشف وفق طبع قدم خدم طبة ضيف خطة تضم دفع عدد عيد تنقل عمل حال خفف ضغط شفي حلة',
#  'nba test present underway golden state soldier face boston celtic soldier defend titlehold seek fourth titl eight time celtic look win first titl sinc 2008 seri verit competit platoon win two game soldier led stephen curri klay thompson draymond green celtic led jayson tatum jaylen brown marcu smart game 6 seri play decid crown seri go seventh decid game celtic win',
#  'ارج تفز كأس علم 2022 فزت ارج كأس علم 2022 غلب رازيل برا نهي ركل رجح نهء وقت اصل ضفي عدل وهذ مرة ثلث تفز ارج كأس فوز لقب عمي 1978 1986 وكان ونل يسي نجم ارج برز حصل جئز فضل لعب بطل سجل يسي هدف صنع هدف خرى تعد مرة ولى تفز ارج كأس علم عام 1986',
#  'drug war spiral ecuadoran elect new presid voter ecuador went poll sunday choos new presid midst drug war rash polit assassin cut short bid popular candid finalist runoff elect lawyer luisa gonzalez 45 banana empir heir daniel noboa 35 campaign bulletproof vest climat fear grip peac south american countri wore vest sunday cast ballot protect arm bodyguard vow prioritis deal escal violenc long line form outsid vote station elect unfold amid heavi polic presenc although immedi report violenc critic elect freddi escobar popular singer told afp cite crime main worri vote inde main concern ecuadoran accord recent poll crime violenc countri murder rate quadrupl four year 2022 polic deploy keep vote safe first preliminari result expect earli even nation elector commiss said today win noboa shout pump fist air vote coastal town olon live gonzalez predict victori cast ballot southwest town canuto hunch ecuador win word citizen revolut said refer name parti drug violenc long major cocain export colombia peru ecuador seen violenc explod recent year enemi gang link mexican colombian cartel vie control fight seen least 460 inmat massacr prison sinc februari 2021 mani behead burn aliv mass riot bloodbath spill street gang dangl headless corps citi bridg deton car bomb outsid polic station show forc',
#  'women sport get decreasingli popular around world recent time signific increas media content women sport girl women share sport lead open women sport world athlet trainer director broadcast illustr us women nation soccer team one popular sport brigad unit state fifa women world cup one watch sport event world rise women sport posit develop gender equival furnish girl women open share sport achiev full eventu',
#  'european union face major energi extrem result war ukrain eu assess warrant russian energi export russia redress cut ga inventori europ led soar energi price put strain busi home across mainland eu scrabbl find indispens sourc energi also work reduc energi consumpt energi extrem major challeng eu like signific impact european frugal extrem also test eu concinn member countri divid respond',
#  'اشو تشو دين انك قدم وجد جبل ديز يرو تم بنؤ قرن خمس وتم تخل عنه وقت لحق قرن سدس كشف جدد عام 1911 بسط امر هيرام أصبح حين وحد اهم وقع ترث علم سكو وجه سيح شهر شهر اشو تشو ببن هندس رئع جمل نظر طبع عبر فهم حضر انك قدم ارخ جذب زور حاء علم ماع جمل ارخ فرد',
#  'experiment set substanti earli mortal exert north america knockout thousand time age preliminarili allow substanti includ graveston tool beast bone set point california discoveri suggest human may arriv north america much earlier preliminarili believ point known cerutti mastodon site locat near citi san diego experiment set number graveston tool point includ scraper copter flake also set bone leviathan larg defunct giant leviathan bone date time old much age former substanti mortal exert north america discoveri cerutti mastodon site major advanc studi earli mortal migrat suggest human may arriv north america much earlier preliminarili allow experiment believ point may butcher point human kill reus leviathan hope farther excav reveal earli human live point',
#  'untouch ancient tomb belong divin inspector uncov egypt known wahty serv royal priest religi figur carri titl divin must someon great import buri southwest outskirt cairo tomb fill colour elabor stone carv give sens ritual life death ancient egypt year ago egyptian antiqu author unveil wahty tomb press confer saqqara southwest cairo weekend announc plan dig deeper complex discov excav work began april astonishingli tomb provid insight life 24th centuri bc reign fifth dynasti egyptian king neferirkar kakair time rel prosper order archaeologist begin inspect five shaft led tomb believ one lead wahty sarcophagu yet discov chamber wall includ scene show wahty wife name weret ptah mother rel well depict potteri furnitur wine product religi ritual music perform naval vessel men hunt anim accord egypt ministri antiqu mostafa waziri egypt suprem council antiqu describ discoveri one kind recent decad colour almost intact even though tomb almost year old reportedli said accord reuter nearli two dozen foreign diplomat member egypt parliament head intern archaeolog mission institut attend unveil tomb saturday egyptian author tout archaeolog discoveri effort entic tourist back countri follow year turmoil ignit arab spring upris',
#  'ولي تحد ارد وقع تفق عزز تعا عسكر وقع ولي تحد ارد تفق عزز تعا عسكر بلد وفر تفق وقع وزر خرج امر نتو بلن وزر خرج ارد ايم صفد ارد 470 ملي كمساعد عسكر مدى سنو خمس قبل تفق علم علق قوة ولي تحد ارد لطل كانت دول ولي تحد ورد رئس سعد عسكر ارد سعد تفق ارد حدث جيش علج تحد مني يجه شكل فضل شمل تحد هدد رهب جمع صرع سمر سور تفق تطر رحب يعد ولي تحد شرق وسط',
#  'scientist discov new speci mortal ancestor south africa speci name homo naledi believ live time agon discoveri help scientist understand elabor mortal rubric remain homo naledi set deep delv system cradl humankind unesco world heritag site locat northwest johannesburg delv system known rise star cave one richest reactionari spot world homo naledi fud set remot chamber rise star cave known dinaledi chamber chamber delic reach believ homo naledi individu designedli place bodi dead chamber homo naledi fud major discoveri complet hominin fud ever set africa furnish scientist new percept elabor mortal rubric fud also help exfoli light relationship homo naledi earli mortal speci similar homo erectu homo neanderthalensi',
#  'نظم مهد قدم عثم نصر ملاذكرد صلح دين يفك دول عمق فطم عرف اهم زرء صلح يقد تبع جرب زرء صلح ارخ سلم خلص فاد نصب ؤسس وزر وصل ذرت صلح فضل رجل وزر صلح دين ايب اخر زرء دول فطم عبر وزر تمت صلح دري علم جذر قذت علم سلم حقب حسس ولم تزل ثمر يجب ارخ شهد سوء طقت عرب رقع سلم متد اسا سطى بلق نظم ملك ولى وزر فوض دول لجق تخذ عدد دبر علم سيس عسكر ادت نهي تمك ذهب اصل فرع طول سنة خطة صلح حيئ جرى عمل قتض عدد دول دول زنك وصل دول ايب دول عثم كانت اخر دول سلم جمع ؤسس وزر فبالتأكيد حضر صور صلح دين وزر دول فطم نجح طبق سيس نظم ملك عدل قضي ظرف سيس وسياقاته تحر برع واج موج لاحق ثور ضاد طئش بطش نظم ملك يدر دول خلف سلط فان مصر كانت حين كمل قرن بعي ذهب خلف فطم عضد وزر صلح دين حمل ترك تقف دول عمق وجد فطم ثقف إدر امر فكك عمل صعب وقد ستع صلح دين أكفأ أقدر رجل حقق همة ولئ نظم ملك فرس مثل طرف وسط داع وفق جنس عرب خلف ترك سلط صلح دين كرد حلة خير مثل عنصر وكل رجل ولى وزر ظل وجد خلف رمز سلط دخل بيئ تمر قلقل ذهب فكر تير نقض ذهب وضم دول شسع منه قطب رحا هندس غير شمل صلح ؤسس',
#  'كريستيانو رونالدو نضم نصر سعد اعل ندي نصر سعد لكر قدم ضمم نجم رتغال كريستيانو رونالدو صفف صفق نقل حر وقع رونالدو لمد عام ندي رتد رقم 7 يعد رونالدو فضل لعب وقد حقق عدد جاز فرد جمع خلل سير احترافية وفز رونالدو خمس كرت لعب ارخ فاز رونالدو بدر بطل ورب ندي مانشستر يتد ريل درد ويوفنتوس نضم رونالدو نصر فسخ عقد ندي مانشستر يتد اضي وكان رونالدو نضم مانشستر يتد 12 غدر ندي جلز ضمم درد أمل نصر سعد رونالدو فرق حقق زيد نجح سنو قبل']

# %% [markdown]
# ### 5. Model Selection + Evaluation
# for this step I want to try three models: (1) Logestic Regression (2) Support Vector Machine (3) Naive Bayes

# %% [markdown]
# #### Logestic Regression

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(X_train_tfidf, y_train)

y_pred_test = logistic_regression.predict(X_test_tfidf)

print("\nLogistic Regression - English and Arabic Data:")
print("Test Accuracy:", accuracy_score(y_test, y_pred_test))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test))
# Out:
# Logistic Regression - English and Arabic Data:
# Test Accuracy: 0.5
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Historical       1.00      1.00      1.00         3
#    Political       0.17      1.00      0.29         1
#       Sports       1.00      0.17      0.29         6
#
#     accuracy                           0.50        10
#    macro avg       0.72      0.72      0.52        10
# weighted avg       0.92      0.50      0.50        10

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(X_train_tfidf, y_train)


y_pred_test_svm = svm_model.predict(X_test_tfidf)

print("\nSupport Vector Machines - English and Arabic Data:")
print("Test Accuracy:", accuracy_score(y_test, y_pred_test_svm))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test_svm))
# Out:
# Support Vector Machines - English and Arabic Data:
# Test Accuracy: 0.2
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Historical       1.00      0.33      0.50         3
#    Political       0.11      1.00      0.20         1
#       Sports       0.00      0.00      0.00         6
#
#     accuracy                           0.20        10
#    macro avg       0.37      0.44      0.23        10
# weighted avg       0.31      0.20      0.17        10
# C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

naive_bayes_model = MultinomialNB()
naive_bayes_model.fit(X_train_tfidf, y_train)

y_pred_test_nb = naive_bayes_model.predict(X_test_tfidf)

print("\nNaive Bayes - English and Arabic Data:")
print("Test Accuracy:", accuracy_score(y_test, y_pred_test_nb))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test_nb))
# Out:
# Naive Bayes - English and Arabic Data:
# Test Accuracy: 0.5
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Historical       1.00      1.00      1.00         3
#    Political       0.17      1.00      0.29         1
#       Sports       1.00      0.17      0.29         6
#
#     accuracy                           0.50        10
#    macro avg       0.72      0.72      0.52        10
# weighted avg       0.92      0.50      0.50        10

# %% [markdown]
# ### 6. Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],  
    'penalty': ['l1', 'l2'],  
}
logistic_regression = LogisticRegression()
grid_search = GridSearchCV(logistic_regression, param_grid, cv=5, scoring='accuracy')

grid_search.fit(X_train_tfidf, y_train)

print("Best Hyperparameters:", grid_search.best_params_)
best_logistic_regression = grid_search.best_estimator_
y_pred_test = best_logistic_regression.predict(X_test_tfidf)

print("\nLogistic Regression - English and Arabic Data (After Hyperparameter Tuning):")
print("Test Accuracy:", accuracy_score(y_test, y_pred_test))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test))
# Out:
# Best Hyperparameters: {'C': 100, 'penalty': 'l2'}
#
# Logistic Regression - English and Arabic Data (After Hyperparameter Tuning):
# Test Accuracy: 0.8
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Historical       1.00      1.00      1.00         3
#    Political       0.33      1.00      0.50         1
#       Sports       1.00      0.67      0.80         6
#
#     accuracy                           0.80        10
#    macro avg       0.78      0.89      0.77        10
# weighted avg       0.93      0.80      0.83        10
# C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 35 fits failed out of a total of 70.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\laraq\OneDrive\Desktop\assignment_2\env\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.39642857        nan 0.39642857        nan 0.39642857
#         nan 0.48214286        nan 0.73928571        nan 0.78928571
#         nan 0.78928571]
#   warnings.warn(

# %%
logistic_regression = LogisticRegression(penalty="l2",C=1000)
logistic_regression.fit(X_train_tfidf, y_train)

y_pred_test = logistic_regression.predict(X_test_tfidf)

print("\nLogistic Regression - English and Arabic Data (After Hyperparameter Tuning):")
print("Test Accuracy:", accuracy_score(y_test, y_pred_test))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test))
# Out:
# Logistic Regression - English and Arabic Data (After Hyperparameter Tuning):
# Test Accuracy: 0.8
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Historical       1.00      1.00      1.00         3
#    Political       0.33      1.00      0.50         1
#       Sports       1.00      0.67      0.80         6
#
#     accuracy                           0.80        10
#    macro avg       0.78      0.89      0.77        10
# weighted avg       0.93      0.80      0.83        10

# %% [markdown]
# ### 7.1 Saving the model using joblib

# %%
import joblib
joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.joblib')
joblib.dump(logistic_regression, 'logistic_regression.joblib')
# Out:
# ['logistic_regression.joblib']

# %% [markdown]
# ### 7.2 Loading the model

# %%
tfidf_vectorizer = joblib.load('tfidf_vectorizer.joblib')
logistic_regression = joblib.load('logistic_regression.joblib')

# %% [markdown]
# ### 8. Testing new files to see whether they get categorized correctly or not

# %%
file_path = "test_file_1.txt"
with open(file_path, 'r', encoding='utf-8') as file:
        article_text = file.read()
preprocessed_text = data_preprocessing_english(article_text)
vectorized_text = tfidf_vectorizer.transform([' '.join(preprocessed_text)])
log_reg_prediction = logistic_regression.predict(vectorized_text)
print("Logistic Regression Prediction:", log_reg_prediction)
# Out:
# Logistic Regression Prediction: ['Sports']

# %%
article_text
# Out:
# 'Embiid scores 41 on return for Sixers, Celtics roll on\nLOS ANGELES — Joel Embiid scored 41 points in a dazzling return from injury on Monday as the Philadelphia 76ers romped past the Houston Rockets 124-115.\n\nKicking off a packed slate of NBA fixtures as the US marked the Martin Luther King Jr. public holiday, the Sixers were always in control as they cruised to victory.\n\nEmbiid missed the Sixers’ past three games after twisting his left knee in a January 5 defeat to the New York Knicks.\n\nBut the NBA’s reigning Most Valuable Player showed no sign of rustiness as he posted his seventh 40-point game of the season, adding 10 rebounds and three assists.\n\nEmbiid shot 12-of-21 from the field and was near-perfect from the foul line, making 16 of 17 free throws in a comfortable win for the Sixers, who improved to 25-13 to remain in third place in the Eastern Conference.\n\nEmbiid’s performance also extended a remarkable scoring streak.\nThe 29-year-old has now gone 16 consecutive games with at least 30 points and 10 rebounds, tying Kareem Abdul-Jabbar for the second-longest streak of its kind in NBA history. Only Wilt Chamberlain is ahead of Embiid and Abdul-Jabbar.\nEmbiid received scoring support in Monday’s rout from Tyrese Maxey with 27 points while Patrick Beverley added 11 from the bench and Tobias Harris 10.\nJalen Green led Houston’s scoring with 20 points while Alperen Sengun finished with 19.\nWhile Embiid made a successful return from injury, there was less to celebrate for Golden State Warriors star Draymond Green in his first game back since missing 16 games through suspension.\nGreen, who was given an indefinite ban by the NBA last month after striking Phoenix Suns player Jusuf Nurkic, played 23 minutes off the bench in the Warriors’ 116-107 loss to the Memphis Grizzlies.\nCeltics roll on \nA close game was settled by a late fourth quarter rally by Memphis, who compiled a 10-1 run to open up a 12-point lead with four minutes remaining.\n“Draymond played well, played hard — it’s good to have him back,” Warriors coach Steve Kerr said after the loss. “Obviously as a team we didn’t play well, but Draymond competed and it’s good to get him back in the fold.” \n\nJalen Green led Houston’s scoring with 20 points while Alperen Sengun finished with 19.\n\nWhile Embiid made a successful return from injury, there was less to celebrate for Golden State Warriors star Draymond Green in his first game back since missing 16 games through suspension.\n\nGreen, who was given an indefinite ban by the NBA last month after striking Phoenix Suns player Jusuf Nurkic, played 23 minutes off the bench in the Warriors’ 116-107 loss to the Memphis Grizzlies.\n\nCeltics roll on \n\nA close game was settled by a late fourth quarter rally by Memphis, who compiled a 10-1 run to open up a 12-point lead with four minutes remaining.\n\n“Draymond played well, played hard — it’s good to have him back,” Warriors coach Steve Kerr said after the loss. “Obviously as a team we didn’t play well, but Draymond competed and it’s good to get him back in the fold.”\n\nIn other games on Monday, Kyrie Irving scored 42 points and Tim Hardaway Jr 41 as the Dallas Mavericks staged a fourth quarter rally to defeat the New Orleans Pelicans 125-120.\n\nIrving and Hardaway scored 20 points between them in the fourth quarter as the Mavericks fought back from a double-digit deficit late in the third to snatch victory.\n\nOnly one other Dallas player — Josh Green, with 13 points — cracked double figures.\n\nDallas coach Jason Kidd meanwhile singled out Hardaway for praise after the 31-year-old slipped seamlessly into the starting line-up due to Luka Doncic’s absence through injury.\n\n“He’s the substitute teacher in the starting line-up and he’s being a pro about it,” Kidd said after the win.\n\n“He’s just a pro. This afternoon was a perfect example of that — he took his shots and was aggressive, and we need that no matter if he’s starting or coming off the bench.”\n\nZ ...

# %% [markdown]
# ### Correct result ✅

# %%
file_path = "test_file_2.txt"
with open(file_path, 'r', encoding='utf-8') as file:
        article_text = file.read()
preprocessed_text = data_preprocessing_arabic(article_text)
vectorized_text = tfidf_vectorizer.transform([' '.join(preprocessed_text)])
log_reg_prediction = logistic_regression.predict(vectorized_text)
print("Logistic Regression Prediction:", log_reg_prediction)
# Out:
# Logistic Regression Prediction: ['Political']

# %%
article_text
# Out:
# '"الإهمال والأمطار واجتياح النمل الأبيض" تهدم أجزاءً من مسجد تاريخي في غانا\nبعد سنوات من الإهمال ومن غزو النمل الأبيض للعوارض والقوائم الخشبية التي تمسك مبنى المسجد، أسقطت الأمطار الغزيرة السقف الطينيّ لمسجد تاريخي في منطقة بولي، شمال غربي غانا، بحسب ما قال مسؤولو الآثار في البلاد.\n\nوأفادت تقارير محلية بأن سقف المسجد انهار يوم الأحد الماضي، إثر أمطار غزيرة أطاحت كذلك بأحد الجسور في المنطقة.\n\nوقد شيّد هذا المسجد، باستخدام الطين في معظمه، في الفترة ما بين أواخر القرن التاسع عشر وأوائل القرن العشرين.\n\nوقال مسؤولون إن المسجد المتضرر يمكن ترميمه بمساعدة من مختصين محليين يعرفون طرازه المعماري وطريقة بنائه، فيما نصحت سلطات الآثار في غانا السكان المحليين بعدم هدم ما بقي قائما من المسجد بُغية بناء مسجد جديد.\n\nوإلى جانب الإهمال وغزو النمل الأبيض، يُعزى تهدّم المسجد التاريخي إلى استخدام مواد البناء الحديثة كالإسمنت في أعمال الترميم والصيانة.\nويتكون سقف المساجد في هذا الطراز من جدائل خشبية مغطاة بالطين، هذه الجدائل مثبتة على قوائم قصيرة منتصبة، وهذه القوائم بدورها تكون مركّبة في دعامات، مما يمنح البناء مظهرا فريدا.\n\nويحمل هذا الطراز المعماري الذي بُني عليه مسجد منطقة بولي، تأثراً بالثقافة السودانية في بناء المساجد، لا سيما في مجتمعات شمالي غانا، وتحديدا منطقتَي والا وكونجا.\n\nوثمة مساجد شبيهة الطراز، مبنية من الطين، في بلدان مجاورة في غرب أفريقيا، لا سيما مالي.\n'

# %% [markdown]
# ### Incorrect result ❎

# %%
file_path = "test_file_3.txt"
with open(file_path, 'r', encoding='utf-8') as file:
        article_text = file.read()
preprocessed_text = data_preprocessing_english(article_text)
vectorized_text = tfidf_vectorizer.transform([' '.join(preprocessed_text)])
log_reg_prediction = logistic_regression.predict(vectorized_text)
print("Logistic Regression Prediction:", log_reg_prediction)
# Out:
# Logistic Regression Prediction: ['Political']

# %%
article_text
# Out:
# 'Donald Trump has won only one 2024 Republican nominating contest. So far. But the ex-president’s political power is growing by the day, propelled by his dominance in national primary polling and the dawning sense that he might be the all-but-inevitable nominee following his resounding win in the Iowa caucuses.\n\nTrump has invigorated an initially lackluster White House bid by leveraging his multiple criminal indictments to create a narrative of political persecution.\n\nHis influence is again dictating terms in Washington, where GOP lawmakers dance to his tune on issues like government funding, Ukraine and immigration, and craft legislative positions to boost his campaign.\n\nFormer President Donald Trump during a campaign event in Portsmouth, New Hampshire, on Wednesday, January 17.\nRELATED ARTICLE\n\ufeffTrump emerges as new obstacle to Senate immigration deal as GOP tension grows\nOn the trail, Trump’s remaining primary opponents, Florida Gov. Ron DeSantis and former South Carolina Gov. Nikki Haley, are gingerly stepping up attacks on him, but they’re pulling their strongest punches over January 6, 2021, and his threat to democracy to avoid angering his supporters. Haley has the best chance to defeat him in an early state when New Hampshire holds its primary on Tuesday, but its electorate isn’t representative of much of the rest of the nominating contests.\n\nAnd there was a Trump-shaped cloud over the World Economic Forum in Davos this week, as European leaders fretted that their nightmare of a Trump 2.0 may be coming true. Business titans were beginning to process the possibility that in one year and a day, a president who shook up the world could be back in the Oval Office. Kevin Roberts – the president of the Heritage Foundation, which has largely become a policy laboratory for a potential second Trump term – ventured into the well-heeled lions’ den at a Swiss alpine resort Thursday and candidly laid out the hardline vision for a new Trump administration that appeared to irk some in the audience.\n\nTrump’s shadow is increasingly looming over Americans who hear his vow to devote a second administration to “retribution.” Such concerns spiked with Trump’s post on Truth Social Thursday, in which he demanded “complete and total” immunity for presidents “even for events that ‘cross the line.’” It’s a stunning vision of unchecked authority even for an ex-president who is arguing in an appeals court he can’t be prosecuted for trying to overturn an election.\n\n‘Scared as heck’\nTrump’s pursuit of a strongman presidency has some Democrats worried. Vice President Kamala Harris confessed this week she was “scared as heck” that Trump could win in November. Ironically, the return of that oppressive unease that characterized his White House years for some of his detractors is what President Joe Biden’s campaign is counting on to carry him to reelection. But given that Trump’s power will rise with every primary vote cast in his favor and the fact he’s running a more professional campaign than he did in 2016 and 2020, Biden perhaps should be careful what he wishes for.\n\nTrump’s enduring weight with Republicans on Capitol Hill has always been unusual for a defeated one-term president and reflected his unbroken bond with GOP base voters. But in the US House of Representatives, especially, Republicans are increasingly mobilizing to push Trump’s political agenda and boost his chance of an election win. On Thursday, CNN’s congressional team reported that senators trying to cut an immigration deal with the White House are running into a problem: Trump.'

# %% [markdown]
# ### Correct result ✅

# %%
file_path = "test_file_4.txt"
with open(file_path, 'r', encoding='utf-8') as file:
        article_text = file.read()
preprocessed_text = data_preprocessing_english(article_text)
vectorized_text = tfidf_vectorizer.transform([' '.join(preprocessed_text)])
log_reg_prediction = logistic_regression.predict(vectorized_text)
print("Logistic Regression Prediction:", log_reg_prediction)
# Out:
# Logistic Regression Prediction: ['Historical']

# %%
article_text
# Out:
# 'At the height of the Viking Age, seafaring Scandinavian warriors reigned supreme in northern Europe and beyond. Yet even as they were terrorizing, say, the British Isles, they were losing the fight against oral bacteria. As it turns out, many Vikings suffered from cavities, plaque buildup, and tooth infections, and they employed various strategies to lessen the pain.\n\nSeveral studies have examined the dental health of Vikings, including one published in December 2023 in the journal PLOS One. For that study, a research team looked at the skeletal remains of 171 Vikings who had been buried in the 10th through 12th centuries outside Varnhem Abbey, the site of the oldest stone church in Sweden.\n\nLife of a Viking, Lead author Carolina Bertilsson, a practicing dentist and associate researcher at the University of Gothenburg, essentially gave each set of Viking teeth a routine checkup. She and two dental students used a bright light, a round dental mirror, and a soft toothbrush to inspect 3,293 total teeth, and then X-rayed some of them to confirm their findings.\n\nAmong Viking children, they couldn’t locate a single cavity, a far cry from today, where even in Sweden—which Bertilsson calls “one of the countries in the world with the best dental health” —roughly 20 percent of 6-year-olds have already developed a cavity. (The rate is far higher in the United States.)\n\nFor Viking adults, though, it was a different story. Over 60 percent of those examined had at least one cavity, and one individual was found with a whopping 22 cavities. Bertilsson and her co-authors also found evidence of plaque and tartar buildup, as well as infections that would have caused painful, pus-filled tooth abscesses. “You can see the traces [of these things] even 1,000 years after,” Bertilsson says.\n\nOne Viking woman in her thirties had a tooth infection so severe it may have killed her, either by obstructing her airways or triggering sepsis. “Even today, it’s a serious condition,” Bertilsson says. “You need to use antibiotics. Sometimes you need to go to the hospital to get treatment.”\nWhat caused all these dental issues? The Viking diet may be at fault. Medieval Scandinavians ate meat, fish, dairy, vegetables, and hazelnuts, all generally fine for oral health. But they also dined on starchy and sweet foods like bread, porridge, honey, and fruits, and they imbibed beer and mead, which over time can bring about chronic tooth disease.\n\nPrevious research shows that other Viking communities, including in Denmark, Scotland, and on the Swedish island of Gotland, likewise suffered from cavities. Icelandic Vikings, on the other hand, appear to have developed relatively few cavities (though they did experience extensive tooth wear), possibly because they didn’t eat as much starch and natural sugar as their less isolated counterparts. \n\nThe Vikings, renowned for their excellent hygiene, did not take these problems lying down. Bertilsson’s team found evidence that they pulled out rotten teeth, and also used toothpicks—a practice that dates back to the Neanderthals—to dislodge bits of stuck food. More surprisingly, Bertilsson’s team identified two instances in which Vikings apparently dug into a tooth’s pulp chamber, likely to relieve the pain of an infection.\n\n“Obviously, they didn’t have anesthetics, so it must have hurt a lot,” says Bertilsson, who adds that the Vikings were not previously known to have performed such a procedure.\n\n(Though unrelated to dental health, some Viking males also filed grooves into their front teeth, possibly as a status or fashion symbol.)'

# %% [markdown]
# ### Correct result ✅

# %%
file_path = "test_file_5.txt"
with open(file_path, 'r', encoding='utf-8') as file:
        article_text = file.read()
preprocessed_text = data_preprocessing_arabic(article_text)
vectorized_text = tfidf_vectorizer.transform([' '.join(preprocessed_text)])
log_reg_prediction = logistic_regression.predict(vectorized_text)
print("Logistic Regression Prediction:", log_reg_prediction)
# Out:
# Logistic Regression Prediction: ['Sports']

# %%
article_text
# Out:
# 'رونالدو: الدوري السعودي أفضل من نظيره الفرنسي.. وهذا ردي على منتقدي انتقالي للمملكة\nأشاد النجم البرتغالي كريستيانو رونالدو بمستوى الدوري السعودي للمحترفين، خلال حضوره حفل توزيع جوائز "غلوب سوكر" عن عام 2023، الذي أقيم في مدينة دبي الإماراتية.\n\nوفاز رونالدو، مهاجم نادي النصر والبالغ من العمر 38 عاماً، بجوائز أفضل لاعب في الشرق الأوسط وأفضل هدّاف واللاعب المفضل لدى الجماهير.\n\nوخلال الحفل، قال كريستيانو رونالدو: "أعتقد أن الدوري السعودي لا يقل عن الدوري الفرنسي، في الدوري الفرنسي، لديك فريقان أو ثلاثة يتمتعون بمستوى جيد، بينما في السعودية، الأمر أكثر تنافسية"، وفقاً لموقع "يورو سبورت".\n\nوأضاف: "يمكن للناس أن يقولوا ما يريدون، لكن لدي رأيي ولقد لعبتُ هناك (في السعودية) لمدة عام، لذا أعرف ما أتحدث عنه، في الوقت الحالي، نحن أفضل من الدوري الفرنسي، وما زلنا نتحسن".\n\nوأكمل رونالدو: "الدوري السعودي سيكون ضمن أفضل 4 دوريات حول العالم، خطوة بخطوة سيصل إلى ذلك".\n\nوردا على المنتقدين لانتقاله إلى المملكة العربية السعودية قبل عام، قال: "الانتقادات الموجهة إلى خطوتي هي جزء من الرحلة، أنا دائماً أتعامل مع ذلك، أنا محترف منذ 22 عاماً، هذا جزء من رحلتي لأكون رجلاً أفضل ولاعباً أفضل".\n\nوتابع قائلاً: "أحب عندما يشكك الناس بي، وأثبت مرة أخرى أنه بعد عام واحد، لقد كنتُ ناجحاً، في العام الماضي، مررتُ برحلة صعبة بعض الشيء، لكنني سعيد بحدوث ذلك لأنه جعلني أشعر بأنني أقوى، وكما ترون، لعبت هذا العام موسماً رائعاً".\n'

# %% [markdown]
# ### Correct result ✅

# %%
file_path = "test_file_6.txt"
with open(file_path, 'r', encoding='utf-8') as file:
        article_text = file.read()
preprocessed_text = data_preprocessing_arabic(article_text)
vectorized_text = tfidf_vectorizer.transform([' '.join(preprocessed_text)])
log_reg_prediction = logistic_regression.predict(vectorized_text)
print("Logistic Regression Prediction:", log_reg_prediction)
# Out:
# Logistic Regression Prediction: ['Political']

# %%
article_text
# Out:
# 'هل يمكن أن يستمر التصعيد بين باكستان وإيران؟\nلقي 9 أشخاص على الأقل مصرعهم، في حصيلة للغارات التي نفذتها باكستان صباح الخميس، على مواقع لمسلحين\ufeff في إقليم سيستان وبلوشستان، في إيران.\n\nوقالت الخارجية الباكستانية إن الغارات "تمت بدقة عالية"، واستهدفت "مواقع عسكرية محددة في إيران"\ufeff.\n\nمن جانبه قال الجيش الباكستاني في بيان إن "المخابيء التي كانت تستخدم من قبل منظمات إرهابية، تم ضربها بنجاح في عملية بنيت على أسس استخباراتية".\n\nوجاءت هذه الغارات الباكستانية، بعد ساعات من غارات إيرانية مشابهة على مواقع قالت إنها لجيش العدل، في الأراضي الباكستانية، وقُتل طفلان على إثرها بحسب الخارجية الباكستانية.\n\nوقد استدعت باكستان سفيرها لدى إيران للتشاور بعد الغارات الإيرانية.\n\nأكد الجيش الباكستاني أنه وبناء على معلومات استخباراتية، استهدف قواعد لتنظيم جيش تحرير بلوشستان وجبهة تحرير بلوشستان داخل الأراضي الإيرانية، وهما تنظيمان متهمان بممارسة الإرهاب في باكستان.\n\nوأضاف الجيش أنه استخدم مسيرات انتحارية، وصواريخ وأسلحة أخرى في غاراته التي تمت بدقة عالية لتفادي "الأضرار الجانبية".\n\nوذكر بيان الجيش الباكستاني أسماء عدة "تنظيمات إرهابية" كانت تسيطر على هذه المواقع، مضيفا أن قواته ستبقى على أهبة الاستعداد لضمان أمن البلاد.\n\nمن جانبه قال نائب مدير أمن إقليم سيستان وبلوشستان الإيراني، علي رضا مرحمتي، إن الهجمات تمت بعد دقائق من الرابعة صباحاً بالتوقيت المحلي، واستهدفت مواقع في قرية قرب مدينة سارافان، القريبة من الحدود مع باكستان.\n\nجيش وجبهة تحرير شعب بلوشستان\nكانت عدة تنظيمات انفصالية تابعة للبلوش، تنشط في المنطقة الواقعة داخل الحدود الباكستانية مع إيران على مدى عقود، وتبنت هجمات استهدفت عناصر الأمن في باكستان.\n\nأكبر هذه التنظيمات، جيش تحرير بلوشستان، بزعامة بشير زاب، وجبهة تحرير بلوشستان التي يتزعمها الدكتور نزار البلوش.\n\nوكانت السلطات الباكستانية تزعم لسنوات أن المسلحين المرتبطين بالانفصاليين البلوش يتخذون من الأراضي الإيرانية مقراً لهم.\n\nلكن وبعد الغارات الإيرانية داخل باكستان أصدرت جبهة تحرير بلوشستان، بياناً قالت فيه إنها لا تمتلك أي قواعد أو مقاتلين داخل الأراضي الإيرانية\ufeff.\n\nومن المعروف أن الجبهة تنشط في المنطقة القريبة من مدينة مكران في إقليم بلوشستان، وتبنت العديد من الهجمات التي استهدفت قوات الأمن الباكستانية.\n\n\ufeffومطلع عام 2022، استهدفت الجبهة المحظورة في باكستان، نقطة تفتيش في مدينة غوادار الباكستانية، وقتل 10 جنود خلال الهجوم.\n\nوكلك تُتهم الجبهة بشن هجمات ضد المقيمين، والعمال الأجانب في باكستان.'

# %% [markdown]
# ### Correct result ✅

# %% [markdown]
# ## End of Project
